# %% [markdown]
#  <h1>An Analysis of the #FeesMustFall Movement through Twitter Data<span class="tocSkip"></span></h1>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Research-Question/Objectives" data-toc-modified-id="Research-Question/Objectives-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Research Question/Objectives</a></span><ul class="toc-item"><li><span><a href="#Research-Questions" data-toc-modified-id="Research-Questions-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Research Questions</a></span></li><li><span><a href="#Objectives" data-toc-modified-id="Objectives-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Objectives</a></span></li></ul></li><li><span><a href="#Dataset" data-toc-modified-id="Dataset-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Dataset</a></span><ul class="toc-item"><li><span><a href="#Scraping-the-data" data-toc-modified-id="Scraping-the-data-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Scraping the data</a></span><ul class="toc-item"><li><span><a href="#Core-data-(using-the-command-line)" data-toc-modified-id="Core-data-(using-the-command-line)-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Core data (using the command line)</a></span></li><li><span><a href="#Benchmark/auxiliary-data-(using-the-Twitter-API)" data-toc-modified-id="Benchmark/auxiliary-data-(using-the-Twitter-API)-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Benchmark/auxiliary data (using the Twitter API)</a></span></li></ul></li><li><span><a href="#Cleaning-the-data" data-toc-modified-id="Cleaning-the-data-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Cleaning the data</a></span><ul class="toc-item"><li><span><a href="#Core-data" data-toc-modified-id="Core-data-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Core data</a></span></li><li><span><a href="#Benchmark-data" data-toc-modified-id="Benchmark-data-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Benchmark data</a></span></li><li><span><a href="#Network-data" data-toc-modified-id="Network-data-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Network data</a></span></li></ul></li></ul></li><li><span><a href="#Visualising-the-data" data-toc-modified-id="Visualising-the-data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Visualising the data</a></span><ul class="toc-item"><li><span><a href="#Objective-1:-Determining-if-Twitter-activity-is-linked-to-protest-action" data-toc-modified-id="Objective-1:-Determining-if-Twitter-activity-is-linked-to-protest-action-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Objective 1: Determining if Twitter activity is linked to protest action</a></span><ul class="toc-item"><li><span><a href="#Unfolding-of-events" data-toc-modified-id="Unfolding-of-events-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Unfolding of events</a></span></li><li><span><a href="#Twitter-as-a-tool-to-mobilise-protestors" data-toc-modified-id="Twitter-as-a-tool-to-mobilise-protestors-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Twitter as a tool to mobilise protestors</a></span></li><li><span><a href="#Summary-of-findings" data-toc-modified-id="Summary-of-findings-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Summary of findings</a></span></li></ul></li><li><span><a href="#Objective-2:-Identifying-key-participants-and-clusters" data-toc-modified-id="Objective-2:-Identifying-key-participants-and-clusters-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Objective 2: Identifying key participants and clusters</a></span><ul class="toc-item"><li><span><a href="#Network-analysis" data-toc-modified-id="Network-analysis-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Network analysis</a></span></li><li><span><a href="#Summary-of-findings" data-toc-modified-id="Summary-of-findings-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Summary of findings</a></span></li></ul></li><li><span><a href="#Objective-3:-Determining-public-perception-towards-the-protests" data-toc-modified-id="Objective-3:-Determining-public-perception-towards-the-protests-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Objective 3: Determining public perception towards the protests</a></span><ul class="toc-item"><li><span><a href="#Text-sentiment-analysis" data-toc-modified-id="Text-sentiment-analysis-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Text sentiment analysis</a></span></li><li><span><a href="#Summary-of-findings" data-toc-modified-id="Summary-of-findings-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Summary of findings</a></span></li></ul></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></div>

# %%
# Import necessary modules
# Some of the these modules will require installation from the command line (e.g. dash, vaderSentiment etc.)

import numpy as np
import pandas as pd
import glob
import datetime as dt
import math
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from pandas.plotting import register_matplotlib_converters
import seaborn as sns
import time
import random
import json
import tweepy
import pickle
import csv
import networkx as nx
from scipy import stats
from operator import itemgetter
from IPython.display import display, HTML
from IPython.display import Image
import dash
import plotly.graph_objs as go
import plotly.express as px
from plotly.subplots import make_subplots
from langdetect import detect 
from textblob import TextBlob 
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import re
from sklearn.metrics import roc_curve, auc
from wordcloud import WordCloud, STOPWORDS
# %matplotlib inline

# Allows side by side dataframe/images in the specified cell
CSS = """
div.cell:nth-child(7) .output {
    flex-direction: row;
}
"""

HTML('<style>{}</style>'.format(CSS))
# Out:
# <style>
# div.cell:nth-child(7) .output {
#     flex-direction: row;
# }
# </style>

# %% [markdown]
# ## Introduction
#
# #FeesMustFall is a South African student-led protest movement born out of the excessively high tuition fees relative to average national income, making higher education inaccessible for most of the population.
#
# During my first year of university in Cape Town, I distinctly remember the sound of gunshots and stun grenades from outside the doors of our residence hall. These were the measures taken by the South African Police Force (SAPS) to control increasingly violent protests. Having been a part of this defining moment in South African education has __motivated__ me to analyse the protests from a statistical perspective.
#
# The protests began in mid-October 2015 and focused on attaining two primary goals:
# 1. Abolish annual increases in tertiary tuition fees.
# 2. Increase government funding of universities.
#
# Protests started at the University of Witwatersrand and spread to the University of Cape Town and Rhodes University. Within several weeks, protests were country-wide ultimately resulting in a national education crisis with an estimated total cost of $44,25 million, just in property damage. Images of protests at two universities during the crisis are shown below.
#
# Having lived among the leaders of the #FeesMustFall movement in Leo Marquard Hall, I recall Twitter playing a major role in mobilising the youth, co-ordinating protests and providing a platform for debate surrounding the topic. This notebook delves deeper into the events of the 2015/2016 education crisis from a data perspective.
#
#
# University of Cape Town    | Wits University
# :-------------------------:|:-------------------------:
# <img src="images/paint.jpg" width="490" height="400"/>  |  <img src="images/fees-must-fall-4.jpg" width="630" height="450"/>
# <img src="images/http---com.ft.imagepublish.prod.s3.amazonaws.com-231fbbce-8caa-11e6-8cb7-e7ada1d123b1.jpg" width="670" height="480"/>|<img src="images/fees-must-faa-3.jpg" width="460" height="450"/>

# %% [markdown]
# ## Research Question/Objectives
#
# ### Research Questions
#
# 1. Is there a correlation between Twitter activity and protest action?
# 2. Who are the central users and influential participants in the protests? Is there a high level of interaction between these users and can any clusters be identified?
# 3. What was the general sentiment surrounding the protests?
# 4. IF YOU GET TO THIS: Are there any subjacent events that can be traced back to the protests?
#
#
# ### Objectives
#
# 1. Provide insight into the volume of tweets with the #FeesMustFall tag over time. Gain a deeper understanding on how the movement gained traction over time by linking tweet volume to significant events. Delve deeper into the link between Twitter activity and protest action.
# 2. Examine the network of tweeters and clusters underlying the core data. Identify key participants, their links and their influence on the movement. Special focus will be given to high profile individuals tweeting on the movement.
# 3. Perform sentiment analysis on the tweets to determine public perception of the protests with the aid of machine learning.
#
# GET RID OF THIS BELOW UNLESS YOU HAVE TIME - MAYBE MENTION IT IN A NEXT STEPS SENTENCE
# 4. Subjacent issues via hashtag analysis lead into next steps. POTENTIALLY CONSIDER CURRENT FEESMUSTFALL TWEETS AS A SUBJACENT ISSUE (I.E. FEESMUSTFALL IN INDIA) (or elsewhere) - using Twitter data as a metric for pre-empting similar movements using the SA example as a benchmark.

# %% [markdown]
# ## Dataset
#
# The data to be analysed in this notebook is drawn from two sources:
#
# 1. __Core data:__  consists of tweets that contain the tag #FeesMustFall taken from the period __21/03/2015 - 31/10/2016__ scraped from the command line.
# 2. __Benchmark data:__ consists of tweets (from __01/02/2017 onwards__) from users who posted at least once with the #FeesMustFall tag. Data was obtained using the Twitter API.
# 3. __Network data:__ consists of a list of nodes and edges as well as a dictionary of user follower counts. The data is primarily obtained by manipulating and shaping the core data. However, additional data in the form of user follower counts is scraped using the Twitter API.
#
# The table below contains information on the core and benchmark data. Variables removed during the cleaning phase are not included.
#
# | Dataset | Tweet count (before clean) | Tweet count (after clean) | Variable 1| Variable 2| Variable 3| Variable 4| Variable 5| Variable 6| Variable 7|
# | ------------------- | ------------- | ----------------------- | ---|---|---|---|---|---|---|
# | Core   | 447204 |352841       |  date	|username	|replies |retweets|	favorites|	text|	mentions|	hashtags|	permalink
# | Benchmark  | 112223    |    27342 |created_at	|text	|favorites	|retweets|	in_reply_to
#
#
#
#
# The table and boxplot below highlight key descriptive statistics of the core data, obtained after the cleaning phase. Statistics are shown for replies, retweets and favourites (collectively referred to as types of engagment). The boxplot is not highly informative, however, it does highlight (HIGHLY SKEWED DATA AND THE POTENTIAL NEED TO ANALYSE THE OUTLIERS - AS THESE ARE THE ONES WITH THE MOST REACH - THEREFORE WE PERFORM SENTIMENT ANALYSIS) clear that while most of the data lies between 0 and 2, there are several outliers with extremely large engagement counts

# %%
sum_stats = pd.read_pickle('pickle_files/sum_stats')
display(sum_stats)
Image(filename='images/summary_boxplot.png')
# Out:
#                             Replies       Retweets     Favourites
# Tweet Count           352841.000000  352841.000000  352841.000000
# Average                    0.206495       2.803835       1.112705
# Standard Deviation         1.314331      22.449769      19.909709
# Min value                  0.000000       0.000000       0.000000
# Lower Quartile (25%)       0.000000       0.000000       0.000000
# Median (50%)               0.000000       0.000000       0.000000
# Upper Quartile (75%)       0.000000       1.000000       1.000000
# Max value                175.000000    3626.000000    8311.000000

# %% [markdown]
# ### Scraping the data
#
# This section includes explanations and code with details on how the various datasets were scraped.
#
# #### Core data (using the command line)
# Twitter have restricted free developer accounts from accessing tweets (by text and tags) further than 7 days in the past. Moreover, the paid API service limits users to 100 daily tweets. These limitations are significant when attempting to perform analysis on more than 350000 tweets. For this reason, alternative scraping methods were utilised to obtain the core data. Marquisvictor's [GetOldTweets repository](https://github.com/marquisvictor/Optimized-Modified-GetOldTweets3-OMGOT) is used as an aid to scrape all tweets from the command line. In essence, this algorithm automates manual scrolling through Twitter. Given the required information, it scrapes Twitter data and metadata directly from the browser.
#
# After installing the relevant packages, all tweets with the #FeesMustFall tag are saved into 4 csv files. Varying periods are used for each csv file to ensure that the scrape is not large enough to lead to a termination of the request. This procedure is carried out as indicated in the image below. Scraping the entire date range took approximately 21 hours.
#
# ![Method used to scrape all historical tweets](images/scrape_data.png "Scrape")

# %%
# Read core data into memory from the scraped csv files

path = r'../2019mt-st445-project-GregAdamMeyer' 
all_files = glob.glob(path + "/*.csv")

csv_li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    csv_li.append(df)

df = pd.concat(csv_li, axis=0, ignore_index=False)
df.head(3)
# Out:
#                date     username   to  replies  retweets  favorites  \
# 0  31/10/2016 23:42  LesIzmoreKC  NaN        0         1          0
# 1  31/10/2016 23:40   SupremeCFC  NaN        2         0          1
# 2  31/10/2016 23:40    camaripop  NaN        0         0          0
#
#                                                 text  geo      mentions  \
# 0  Seven university protests around the world tha...  NaN  @thedailyvox
# 1  So now at CUT every student qualifies to write...  NaN           NaN
# 2  Thought Factory: #FeesMustFall: So Why Shutdow...  NaN           NaN
#
#                                             hashtags            id  \
# 0                                      #FeesMustFall  7.930000e+17
# 1                                      #FeesMustFall  7.930000e+17
# 2  #FeesMustFall #SouthAfrica #BLM #leadership #i...  7.930000e+17
#
#                                            permalink
# 0  https://twitter.com/LesIzmoreKC/status/7932366...
# 1  https://twitter.com/SupremeCFC/status/79323619...
# 2  https://twitter.com/camaripop/status/793236161...

# %% [markdown]
# #### Benchmark/auxiliary data (using the Twitter API)
#          -- will be referred to as the benchmark data
# This notebook proceeds to use the Twitter API to scrape tweets from random users who tweeted with the #FeesMustFall tag in the data above in order to draw conclusions about the engagement surrounding #FeesMustFall. Unlike the case with the core data, tweets older than 7 days can be scraped _using the API_ provided the search parameter is the user's screen name and not the tweet text. During the cleaning phase, I only take tweets from 4 months after the protests onwards to ensure this data is not related to #FeesMustFall and hence a good benchmark against which to compare the core data. Scraping the data below took approximately 1 hour.

# %%
# Scrape auxilary data from Twitter API and read it into memory

# Load credentials from json file
with open("../2019mt-st445-project-GregAdamMeyer/twitter_api.json", 
          "r") as file:
    secrets = json.load(file)

api_key = secrets['CONSUMER_KEY']
api_secret_key = secrets['CONSUMER_SECRET']
access_token = secrets['ACCESS_TOKEN']
access_token_secret = secrets['ACCESS_SECRET']

auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
    
def get_tweets(screen_name):
    tweets = []
    # Initial request
    new_tweets = api.user_timeline(screen_name = screen_name,count=200)
    tweets.extend(new_tweets)
    # Save the id of the oldest tweet less one to avoid duplication
    oldest = tweets[-1].id - 1
    # Extract tweets until there are none left
    while len(new_tweets) > 0:
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
        tweets.extend(new_tweets)
        oldest = tweets[-1].id - 1
    
    # Transform array into a format that will be written to a csv file
    outtweets = [[tweet.created_at, tweet.text, tweet.favorite_count, tweet.retweet_count, 
                  tweet.in_reply_to_screen_name] for tweet in tweets]
    # Write to csv
    with open('../2019mt-st445-project-GregAdamMeyer/random_users/' 
            + '%s_tweets.csv' % screen_name, 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["created_at","text","favorites","retweets",
                         "in_reply_to"])
        writer.writerows(outtweets)

# Obtain a list of unique users who tweeted with the #FeesMustFall tag
users = set(df['username'])        

# Take 50 of the users above, get their most recent tweets and save them to csv files
# for count, user in enumerate(users):
#     get_tweets(user)
#     if count == 50:
#         break 

# Read the benchmark data into memory from the csv files
path = r'../2019mt-st445-project-GregAdamMeyer/random_users' 
user_files = glob.glob(path + "/*.csv")

csv_l = []

for users in user_files:
    df_rnd = pd.read_csv(users, index_col=None, header=0)
    csv_l.append(df_rnd)

df_rnd = pd.concat(csv_l, axis=0, ignore_index=False)
df_rnd.head(3)
# Out:
#             created_at                                               text  \
# 0  2020-01-05 19:32:58  @ThatoMamathuba @tds122 Awwww Tony 💓❤ LOL we a...
# 1  2020-01-05 19:27:56  @tds122 @ThatoMamathuba Yeah versus Eng it's 3...
# 2  2020-01-05 19:23:45      @juliantsepo You do understand humour, right?
#
#    favorites  retweets     in_reply_to
# 0          2         0  ThatoMamathuba
# 1          2         0          tds122
# 2          1         0     juliantsepo

# %% [markdown]
# ### Cleaning the data
# #### Core data
#
# The following steps are carried out during the initial data clean:
# 1. Drop all duplicate rows that arise as a result of an overlap in web scrape dates.
# 2. Convert dates to datetime objects.
# 3. Remove all replies - for the purpose of this analysis, I am only interested in tweets. I store replies in an alternative dataframe which will be used for engagement analysis.
# 4. Drop unwanted columns
#     - Since a user can optionally link their tweet to a geographic location, selecting tweets based on geotags significantly decreases the number of extracted tweets. For this reason, geographical analysis does not form part of this investigation.
#     - Some preliminary analysis has shown that the scraping produced several tweets with the same ID - for this reason I drop the ID column and reference each tweet by an index number, sorted in chronological order.
# 5. Lastly, this notebook manipulates the dataframe to produce statistics summarising certain metrics of the data - the resulting figure from this code is the boxplot shown in the Dataset section.
#
# Different versions of the core dataframe are required for different visualisations of the data. The initial data clean is done in this section, and further ad hoc data pivots, groupbys and other cleaning methods are performed throughout the notebook.

# %%
# Clean core data

# First drop the duplicates in each scraped csv due to overlapping scrape dates
# Subset by permalink as these links will be unique
df.drop_duplicates(keep = 'first', inplace = True, subset = 'permalink')
df['date'] = pd.to_datetime(df['date'], dayfirst = True)
df_replies = df[~df['to'].isnull()] # keep the replies in a different dataframe
df = df[df['to'].isnull()] # only want tweets that aren't replies
df.drop(columns=['to', 'geo', 'id'], inplace = True) # drop unwanted columns
df.sort_values(by = 'date' ,inplace = True)
df = df.reset_index()
df.drop(columns='index', inplace = True) # drop extra index column
display(df.head(3))
# df will remain unchanged and act as the core data - manipulations and pivots will be 
# performed on copies of this dataframe

# =======================================================================================

# Provide descriptive stats on the core data
sum_stats = df.describe()
# Improve formatting of summary stats
sum_stats.rename({'count': 'Tweet Count', 'mean': 'Average',
                 'std': 'Standard Deviation', 'min': 'Min value',
                 '25%': 'Lower Quartile (25%)', '50%': 'Median (50%)', 
                 '75%': 'Upper Quartile (75%)', 'max': 'Max value'},
                 axis='index', inplace = True)
sum_stats.rename({'replies': 'Replies', 'retweets': 'Retweets',
                 'favorites': 'Favourites'},
                 axis='columns', inplace = True)


# Save to pickle file so df can be shown in Dataset chapter
sum_stats.to_pickle('pickle_files/sum_stats')

engage_bplot1 = df[['replies']]
engage_bplot1 = engage_bplot1.rename({'replies': 'Num_engagements'} ,axis = 'columns')
engage_bplot1['Type'] = 'Reply'
engage_bplot2 = df[['retweets']]
engage_bplot2 = engage_bplot2.rename({'retweets': 'Num_engagements'} ,axis = 'columns')
engage_bplot2['Type'] = 'Retweet'
engage_bplot3 = df[['favorites']]
engage_bplot3 = engage_bplot3.rename({'favorites': 'Num_engagements'} ,axis = 'columns')
engage_bplot3['Type'] = 'Favourite'

engage_plot = engage_bplot1.append(engage_bplot2).append(engage_bplot3)

fig, ax = plt.subplots()
sns.boxplot(data=engage_plot, x = 'Type', y = 'Num_engagements')
plt.ylim(0,5)
plt.xlabel('Engagement type',labelpad = 12)
plt.ylabel('Number of engagements' ,labelpad = 12)
plt.title('Boxplots for different engagement types')
fig.tight_layout()
plt.savefig('images/summary_boxplot.png', dpi=300)
plt.close(fig)
# Out:
#                  date        username  replies  retweets  favorites  \
# 0 2015-03-21 14:28:00  SkhumbuzoTuswa        2         3          6
# 1 2015-04-07 04:31:00        SSSIBIYA        0         1          3
# 2 2015-10-13 17:07:00    SmartBlackZA        0         6          1
#
#                                                 text      mentions  \
# 0  Priorities?? #FeesMustFall RT @informer_sa: UC...  @informer_sa
# 1  #FEESMustFall that will make sense to me. Free...           NaN
# 2  Now it is time for me to mobilize Wits student...           NaN
#
#                         hashtags  \
# 0  #FeesMustFall #RhodesMustFall
# 1                  #FEESMustFall
# 2                  #FeesMustFall
#
#                                            permalink
# 0  https://twitter.com/SkhumbuzoTuswa/status/5792...
# 1  https://twitter.com/SSSIBIYA/status/5852989398...
# 2  https://twitter.com/SmartBlackZA/status/653980...

# %% [markdown]
# #### Benchmark data
# The benchmark data is cleaned in a similar manner to the core data. However, due to the contrasting output format as a result of using the API, as well as the purpose for which this data is to be used, two additional steps are taken:
#
# 1. I only retain tweets occurring from February 2017 onwards to ensure that most tweets in this dataset are not linked to #FeesMustFall. This allows for comparison of the engagement distribution over time between #FeesMustFall tweets vs non #FeesMustFall tweets.
# 2. The scraped dataset contains retweets - these tweets removed to focus on the analysis of original tweets. Retweets distort temporality and volume analysis.

# %%
# Clean benchmark tweet data

df_rnd['created_at'] = pd.to_datetime(df_rnd['created_at'])
df_rnd.head(15)
# Only want tweets from well after the protest to ensure that the bulk of 
# these tweets are not related to the #FeesMustFall topic - this will allow
# for a more accurate comparison 
df_rnd = df_rnd[df_rnd['created_at'] > dt.datetime(2017,2,1,0,0,0)]
df_rnd.drop_duplicates(inplace = True)
df_rnd = df_rnd[df_rnd['in_reply_to'].isnull()] # don't want tweets that are replies
# Dataset contains retweets - need to remove retweets to obtain only user original tweets
df_rnd = df_rnd.reset_index()
# Create a column with the first two letters of the tweet
df_rnd['first_2_letters'] = df_rnd['text'].astype(str).str[0:2]
# Remove retweets 
df_rnd = df_rnd[df_rnd['first_2_letters']!='RT']
df_rnd = df_rnd.reset_index()
df_rnd.drop(columns=['index', 'first_2_letters', 'level_0'], inplace = True)
df_rnd.tail(3)
# Out:
#                created_at                                               text  \
# 27339 2017-02-03 12:18:00  one person followed me and one person unfollow...
# 27340 2017-02-03 10:54:08  #Droogte: Dis mos nou hoe jy #reën vier! Boere...
# 27341 2017-02-01 09:25:36  #RareKanker: Bloem-vrou sterf ná stryd teen ra...
#
#        favorites  retweets in_reply_to
# 27339          0         0         NaN
# 27340          0         0         NaN
# 27341          0         0         NaN

# %% [markdown]
# #### Network data
# This notebook proceeds to shape the core data for network analysis as well as scrape more data using the Twitter API.
# First, an undirected network is created. This is in the form of a list where each element consists of two connected nodes in set format. Nodes/users are considered to be connected in a #FeesMustFall context if the users have interacted via mentions or replies. A network with 112011 edges is obtained.
#
# Next, I create a dictionary of all users in the core data with each user's corresponding follower count as the dictionary value. This will be used to limit the network analysis to __500__ users. Not only does this aid visualisation, but it also allows me to restrict the network analysis to users with far reach.
#
#
#
# MAYBE EXPLAIN STEPS IN CLEANING PROCESS BELOW - IF YOU HAVE TIME, GIVE WEIGHTS BASED ON NUMBER BUT DO THIS IN A DIFFERENT NOTEBOOK
# OF INTERACTIONS
#
# The following steps were taken to clean and shape the data for network analysis:
#
# 1. Subset *df* to contain rows where mentions are made.
# 2. Cycle through this dataframe (*df_nx*) and the replies dataframe (*df_replies*) adding required edges to the *ntwrk* array. When adding edges from *df_nx*, the *parse_mentions* function is used to remove unwanted characters.
# 3. Lastly, follower counts for all users found in the network are scraped using the Twitter API. HOWEVE MENTION IF SOME FOLLOWERS CANT BE SCRAPED. 243532453 followers cannot be retrieved as these followers have deleted their accounts. They are excluded from the analysis.

# %%
# Create network of nodes and edges

# First, create a network consisting of all users
# Later on, trim the network to include high profile users using the dict above

# Subset tweets that have mentions
df_nx = df[~df['mentions'].isnull()][['username', 'mentions']]
df_nx.reset_index(inplace = True)
df_nx.drop(columns = 'index', inplace = True)

def parse_mentions(mentions):
    '''Parses all the mentions for a specific tweet
    as a list and removes the @ symbol'''
    m_list = mentions.split()
    for i in range(len(m_list)):
        m_list[i] = m_list[i].lstrip('@')
    
    return m_list

# Cycle through all user/mention combinations and add them
# to the ntwrk list if they are not already there
ntwrk = []
for entry in df_nx.itertuples():
    for each_mention in parse_mentions(entry.mentions):
        n_edge = {entry.username, each_mention}
        if n_edge not in ntwrk:
            ntwrk.append(n_edge)

# Next, cycle through all user replies and add them to the ntwrk
# list if they are not already there
df_replies = df_replies[['username', 'to']]
for entry in df_replies.itertuples():
    n_edge = {entry.username, entry.to}
    if n_edge not in ntwrk:
        ntwrk.append(n_edge)

# Remove people who mention/reply to themselves
ntwrk_no_self_mentioners = []
for i in ntwrk:
    if len(i) == 2:
        ntwrk_no_self_mentioners.append(i)
        
ntwrk = ntwrk_no_self_mentioners

#==============================================================================
# Now, create a dictionary of all users follower counts to limit the network
# analysis later on in the notebook

# Update users after core clean has been performed
users = set(df['username']) 
# Create a dict of users and corresponding follower counts scraped from Twitter
# This process took 52 hours and misses several users due to Twitter's rate limits
follow_dict = {}
user_not_found = []

# # Do not run the code below again - it was used to initialy create the follower count dict
# for each_user in users:
#     try:
#         user_info = api.get_user(each_user)
#         follow_dict[user_info.screen_name] = user_info.followers_count
#     except:
#         user_not_found.append(each_user)
        
# with open('pickle_files/follow_dict.pickle', 'wb') as handle:
#     pickle.dump(follow_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
    

# NBNBNB DELETE THIS BELOW IF THE CELL BELOW WORKS    
# # Due to Twitters rate limits, the previous scrape did not return all required users
# # Obtain the remaining users below:
# with open('pickle_files/follow_dict.pickle', 'rb') as handle:
#     follow_dict = pickle.load(handle)

# # 5858 users not found (length of user_not_found list)
# user_not_found1 = []
# for each_user in user_not_found:
#     try:
#         user_info = api.get_user(each_user)
#         follow_dict[user_info.screen_name] = user_info.followers_count
#     except:
#         user_not_found1.append(each_user)   
        
# # 495 users still not found

# user_not_found2 = []
# for each_user in user_not_found1:
#     try:
#         user_info = api.get_user(each_user)
#         follow_dict[user_info.screen_name] = user_info.followers_count
#     except:
#         user_not_found2.append(each_user)
        
# # 272 users still not found

# user_not_found3 = []
# for each_user in user_not_found2:
#     try:
#         user_info = api.get_user(each_user)
#         follow_dict[user_info.screen_name] = user_info.followers_count
#     except:
#         user_not_found3.append(each_user)
        
# with open('pickle_files/updated_follow_dict.pickle', 'wb') as handle:
#     pickle.dump(follow_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
# # 272 users still not found

# # Some desktop research showed that all 263 users have deleted their accounts 
# # follow_dict is not updated further

# %%
# Due to Twitters rate limits, the previous scrape did not return all required users
# Moreover, there are users who were replied to but did not tweet that haven't been extracted
# Remaining users are obtained below:

with open('pickle_files/follow_dict.pickle', 'rb') as handle:
    follow_dict = pickle.load(handle)

cnt = 0
for node1, node2 in ntwrk:
    if node1 not in follow_dict:
        try:
            user_info = api.get_user(node1)
            follow_dict[user_info.screen_name] = user_info.followers_count
        except:
            cnt+=1
    if node2 not in follow_dict:
        try:
            user_info = api.get_user(node2)
            follow_dict[user_info.screen_name] = user_info.followers_count
        except:
            cnt+=1  

# cnt = 31094 users in the ntwrk data still not found

# Rerun code above to obtain missing users - run until new users are no longer obtained
prev_cnt = 1 # initialise prev_cnt that does not equal cnt 
while prev_cnt!=cnt:
    prev_cnt = cnt
    cnt = 0
    for node1, node2 in ntwrk:
        if node1 not in follow_dict:
            try:
                user_info = api.get_user(node1)
                follow_dict[user_info.screen_name] = user_info.followers_count
            except:
                cnt+=1
        if node2 not in follow_dict:
            try:
                user_info = api.get_user(node2)
                follow_dict[user_info.screen_name] = user_info.followers_count
            except:
                cnt+=1  
            
# cnt = 22758 users in the first iteration, 22165 in the second
# after the while loop has completed, 1252435634 users are still not found 
            
#NBNBNBNB SAVE THE NEW FOLLOW DICT AS A PICKLE FILE TO UPDATED FOLLOW DICT
#  BUT BUT FIRST DELETE UPDATED FOLLOW DICT 


# Some desktop research showed that all 263 users have deleted their accounts 
# follow_dict is not updated further

# %%
cnt
# Out:
# 22758

# %% [markdown]
# ## Visualising the data
#
# ### Objective 1: Determining if Twitter activity is linked to protest action
#
# #### Unfolding of events
#
# The #FeesMustFall movement kicked off after the announcement that university fees for 2016 would increase by 10.5%. The tweet below summarises how many students felt. Much of the momentum the protests gained can be attributed to these feelings.
#
# <img src="images/explanation.jpg" width="400" height="300"/>
#
# Firstly, this section gives a brief overview of the unfolding of events. Secondly, the section explores whether the prominence of the #FeesMustFall movement and periods of intense protest was linked to the volume of tweets over time.

# %%
# Plot volume of tweets by date

df_man = df.iloc[:]
df_man['date'] = df['date'].dt.floor('T') # remove seconds - allows for better plot visualisation
df_man['date_temp'] = [i.date() for i in df_man['date']]
volume = (df_man.groupby('date_temp')['username'].count())

register_matplotlib_converters()
fig, ax = plt.subplots(figsize=(18, 6))

plt.plot(volume,'r')
plt.title('Number of #FeesMustFall tweets over time', fontsize = 15)
ax.set_facecolor('whitesmoke')
plt.xlabel('Date')
plt.ylabel('Tweet Frequency')
plt.xlim([dt.date(2015,9,1), dt.date(2016,11,15)])
# Plot dashed lines to show periods of intense protests
plt.axvline(dt.date(2015, 10, 8), color='b', linestyle='dashed', linewidth=1)
plt.axvline(dt.date(2015, 10, 29), color='b', linestyle='dashed', linewidth=1)
plt.axvline(dt.date(2016, 9, 19), color='b', linestyle='dashed', linewidth=1)
plt.axvline(dt.date(2016, 10, 28), color='b', linestyle='dashed', linewidth=1)

plt.show()

# %% [markdown]
# The plot above gives some insight into the periods of peak Twitter activity. The dashed blue lines represent the start and end dates of heightened protests for each respective year. The link between Twitter activity and protest actions is explored further in the next plot.

# %%
# Create interactive volume plot

volume_df = pd.DataFrame(volume)
volume_df = volume_df.rename({'username': 'tweet_count'} ,axis = 'columns')
volume_df['date'] = volume_df.index
volume_df['year'] = volume_df['date'].map(lambda x: x.year)
volume_df['month'] = volume_df['date'].map(lambda x: x.month)

# We now create the points for the significant dates to be marked on the plotly line graph
signif_dates = [dt.date(2015,9,14),dt.date(2015,10,8),dt.date(2015,10,14),
                dt.date(2015,10,19),dt.date(2015,10,20),dt.date(2015,10,21),
                dt.date(2015,10,23),dt.date(2015,11,1),dt.date(2016,9,19),
                dt.date(2016,10,10),dt.date(2016,10,19),dt.date(2016,11,1)]
for day in signif_dates: # add significant dates with zero tweet count to dataframe
    if day not in volume_df.index:
        volume_df.loc[day] = [0, day, day.year, day.month]
volume_df.sort_values(by = 'date' ,inplace = True)

scatter_df = volume_df[volume_df.index.isin(signif_dates)]

volume_df[volume_df.index.isin([dt.date(2015,11,1),dt.date(2016,10,15)])]

# fig = px.line(volume_df, x = volume_df.index, y = 'tweet_count', 
#               title='Number of #FeesMustFall tweets over time',
#               color = 'year', hover_name = 'date')

fig = px.line(volume_df, x = volume_df.index, y = 'tweet_count', 
              title='Number of #FeesMustFall tweets over time',
              color = 'year', labels = {'year':'Year', 'tweet_count': 'Tweet Count',
                                       'x':'Date'})

actual_text = ['<br>Signs of student unrest in KZN</br>',
               '<br>First major protest </br> Presidential task team announced',
               '<br>Birth of the #FeesMustFall movement </br> Systematic shutdown of \
               South African universities <br>Protests escalate</br>',
               '<br>Protests are countrywide</br>Courts grant interdicts against students <br>\
               Police and students engage in violent confrontations</br>',
               '<br>6% fee increase announced </br>Students reject this proposition',
               '<br>Parliamentary grounds are breached </br>Students controlled with stun grenades,\
               teargas and riot shields<br>Multiple arrests take place</br>',
               '<br>0% fee increase announced </br>Protests reach their peak <br>Riots in Pretoria\
               - police vehicles are burned</br>',
               '<br>Protests start losing momentum </br>Lectures take place online\
               <br>Students given the option to defer exams</br>',
               '<br>8% fee increase for 2016 announced </br>Movement regains momentum\
               <br> Universities shut down and move to online lectures </br>',
               '<br>Rubber bullets, stun grenades and smoke grenades fired at students\
               attempting to enter the Great Hall at Wits</br>',
               '<br>Two security guards beaten by students at UCT </br>Private security\
               companies contracted to protect the campus',
               '<br>Steel strucure exam venue constructed on the UCT rugby field </br>\
               Exam venue secured by private security and canine units']
hovertext = ['<b>' + str(day) + '</b>' + actual_text[i] for i, day in enumerate(signif_dates)]

fig.add_trace(go.Scatter(
    x=scatter_df.index,
    y=scatter_df.tweet_count,
    mode='markers',
    name='markers',
    hovertext=hovertext,
    hoverinfo="text",
    marker=dict(
        color="green",
        size = [10]*12
    ),
    showlegend=False
))

fig.update_layout(xaxis_title="Date", yaxis_title="Tweet Frequency",
                 xaxis_range=[dt.date(2015,9,1), dt.date(2016,11,15)],
                 xaxis_rangeslider_visible=True)



# fig.update_layout(showlegend=False)
    
fig.show()
# Out:
# <div>
#
#
#             <div id="6bb744f2-9c42-4007-a312-36e9f496a900" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6bb744f2-9c42-4007-a312-36e9f496a900")) {
#                     Plotly.newPlot(
#                         '6bb744f2-9c42-4007-a312-36e9f496a900',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Year=2015<br>Date=%{x}<br>Tweet Count=%{y}", "legendgroup": "Year=2015", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Year=2015", "showlegend": true, "type": "scatter", "x": ["2015-03-21", "2015-04-07", "2015-09-14", "2015-10-08", "2015-10-13", "2015-10-14", "2015-10-15", "2015-10-16", "2015-10-17", "2015-10-18", "2015-10-19", "2015-10-20", "2015-10-21", "2015-10-22", "2015-10-23", "2015-10-24", "2015-10-25", "2015-10-26", "2015-10-27", "2015-10-28", "2015-10-29", "2015-10-30", "2015-10-31", "2015-11-01", "2015-11-02", "2015-11-03", "2015-11-04", "2015-11-05", "2015-11-06", "2015-11-07", "2015-11-08", "2015-11-09", "2015-11-10", "2015-11-11", "2015-11-12", "2015-11-13", "2015-11-14", "2015-11-15", "2015-11-16", "2015-11-17", "2015-11-18", "2015-11-19", "2015-11-20", "2015-11-21", "2015-11-22", "2015-11-23", "2015-11-24", "2015-11-25", "2015-11-26", "2015-11-27", "2015-11-28", "2015-11-29", "2015-11-30", "2015-12-01", "2015-12-02", "2015-12-03", "2015-12-04", "2015-12-05", "2015-12-06", "2015-12-07", "2015-12-08", "2015-12-09", "2015-12-10", "2015-12-11", "2015-12-12", "2015-12-13", "2015-12-14", "2015-12-15", "2015-12-16", "2015-12-17", "2015-12-18", "2015-12-19", "2015-12-20", "2015-12-21", "2015-12-22", "2015-12-23", "2015-12-24", "2015-12-25", "2015-12-26", "2015-12-27", "2015-12-28", "2015-12-29", "2015-12-30", "2015-12-31"], "xaxis": "x", "y": [1, 1, 0, 0, 3, 37, 37, 44, 23, 60, 6562, 17318, 49954, 57923, 67885, 4784, 2764, 5588, 3543, 2546, 1562, 928, 402, 437, 624, 580, 712, 713, 565, 213, 321, 754, 375, 636, 515, 411, 186, 275, 409, 356, 223, 219, 182, 96, 87, 138, 179, 104, 150, 107, 62, 117, 114, 91, 87, 193, 64, 44, 23, 59, 79, 93, 192, 131, 67, 78, 81, 164, 344, 90, 85, 38, 31, 57, 43, 34, 49, 12, 28, 18, 43, 118, 94, 115], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Year=2016<br>Date=%{x}<br>Tweet Count=%{y}", "legendgroup": "Year=2016", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Year=2016", "showlegend": true, "type": "scatter", "x": ["2016-01-01", "2016-01-02", "2016-01-03", "2016-01-04", "2016-01-05", "2016-01-06", "2016-01-07", "2016-01-08", "2016-01-09", "2016-01-10", "2016-01-11", "2016-01-12", "2016-01-13", "2016-01-14", "2016-01-15", "2016-01-16", "2016-01-17", "2016-01-18", "2016-01-19", "2016-01-20", "2016-01-21", "2016-01-22", "2016-01-23", "2016-01-24", "2016-01-25", "2016-01-26", "2016-01-27", "2016-01-28", "2016-01-29", "2016-01-30", "2016-01-31", "2016-02-01", "2016-02-02", "2016-02-03", "2016-02-04", "2016-02-05", "2016-02-06", "2016-02-07", "2016-02-08", "2016-02-09", "2016-02-10", "2016-02-11", "2016-02-12", "2016-02-13", "2016-02-14", "2016-02-15", "2016-02-16", "2016-02-17", "2016-02-18", "2016-02-19", "2016-02-20", "2016-02-21", "2016-02-22", "2016-02-23", "2016-02-24", "2016-02-25", "2016-02-26", "2016-02-27", "2016-02-28", "2016-02-29", "2016-03-01", "2016-03-02", "2016-03-03", "2016-03-04", "2016-03-05", "2016-03-06", "2016-03-07", "2016-03-08", "2016-03-09", "2016-03-10", "2016-03-11", "2016-03-12", "2016-03-13", "2016-03-14", "2016-03-15", "2016-03-16", "2016-03-17", "2016-03-18", "2016-03-19", "2016-03-20", "2016-03-21", "2016-03-22", "2016-03-23", "2016-03-24", "2016-03-25", "2016-03-26", "2016-03-27", "2016-03-28", "2016-03-29", "2016-03-30", "2016-03-31", "2016-04-01", "2016-04-02", "2016-04-03", "2016-04-04", "2016-04-05", "2016-04-06", "2016-04-07", "2016-04-08", "2016-04-09", "2016-04-10", "2016-04-11", "2016-04-12", "2016-04-13", "2016-04-14", "2016-04-15", "2016-04-16", "2016-04-17", "2016-04-18", "2016-04-19", "2016-04-20", "2016-04-21", "2016-04-22", "2016-04-23", "2016-04-24", "2016-04-25", "2016-04-26", "2016-04-27", "2016-04-28", "2016-04-29", "2016-04-30", "2016-05-01", "2016-05-02", "2016-05-03", "2016-05-04", "2016-05-05", "2016-05-06", "2016-05-07", "2016-05-08", "2016-05-09", "2016-05-10", "2016-05-11", "2016-05-12 ...

# %% [markdown]
# Given information surrounding pivotal events in the movement, it becomes clear that there is a strong correlation between tweet frequency and protest action. Hover over the **green circles** above for information on events occurring on specific dates. You can also use the range slider at the bottom to restrict the dates in view.
#
# The significant events corresponding to the **green circles** above are described in greater detail below:
#
# 1. **14 September 2015**: The first protests voicing student dissatisfaction with high fees occurs at UKZN. Students set fire to buildings and engage in battles with police and security. The #FeesMustFall tag is yet to be created as evidenced by the figure above.
# 2. **8 October 2015:** The first major protest against outsourcing and tuition fee increases - the president is now involved. He announces a task team to investigate solutions.
# 3. **14 October 2015:** Escalation of protests - the start of a systematic shutdown of universities across South Africa. Entrances to universities are blocked. #FeesMustFall is announced as a formal movement on this day.
# 4. **15-18 October 2015:** Protests continue to escalate - the movement is gaining traction
# 5. **19 October 2015:** Protests spread to all parts of the country - court interdicts are obtained authorising police to engage with students on campus.
# 6. **20 October 2015:** Minister of higher education, Nzimande, announces a cap of 6% on fee increases - students reject this.
# 7. **21 October 2015:** Chaos erupts - 5000 UCT and CPUT break into the national parliamentary grounds resulting in violent engagement with police. Students are removed with stun grenades, riot shields and batons. Multiple arrests take place. Similar scenes occur at NMMU in Port Elizabeth where students are pushed back by rubber bullets and teargas.
# 8. **23 October 2015:** Announcement of a 0% fee increases by the president in Pretoria. However, the crowd becomes angered that the president does not descend to the grounds to address them. Riots, burning of police vehicles, rubber bullets, teargas and flash-bangs ensue.
# 9. **November 2015:** Protests slowly lose momentum after the 0% fee increase announcement. Classes at university do not resume and students are lectured online. Exams proceed under heightened security. Students are given the option to defer exams to the following year.
# 10. **19 September 2016:** Protests continue into 2016, but with less momentum than in 2016. This can be seen by the significantly lower tweet volume. The movement regains momentum when an 8% fee increased is announced. Universities shut down and shift to an online learning platform.
# 11. **10 October 2016:** Police fire rubber bullets, stun grenades and smoke grenades at students attempting to gain access into the Wits Great Hall.
# 12. **19 October 2016:** Two security guards are beaten with steel rods taped with masking tape at UCT. Private security companies are contracted to control protests on campus.
# 13. **November 2016:**: A steel structure on the UCT rugby field is constructed allowing security to successfully lockdown the exam venue. The venue is heavily secured by armed specialist security forces and canine units.
#
# *_UKZN - University of KwaZulu-Natal_ (Durban)
# *_UCT - University of Cape Town_ (Cape Town)
# *_Wits - University of the Witwatersrand_ (Johannesburg)
# *_CPUT - Cape Peninsula University of Technology_ (Cape Town)
# *_NMMU - Nelson Mandela Metropolitan University_ (Port Elizabeth)
#
#
# From the above, it is clear that a spike in tweets with the tag #FeesMustFall coincided with periods of heavy protest action and defining events. The strong link between Twitter activity and protest action is apparent. SOMEHOW SPLIT THIS CONCLUSION BETWEEN HERE AND HOURLY GRAPH.
#
#
#
# MAYBE
# Discuss reasons why the second season was not as popular - also, trend was more stable because people were expecting another protest. Lots of tweets over a longer period of time in 2016 where as 2015 there were a lot at once.

# %% [markdown]
# #### Twitter as a tool to mobilise protestors

# %%
# Plot tweet volume by time of day

# Group tweets by the time of day they were tweeted
df_man['time_temp'] = [i.time() for i in df_man['date']]
volume_time = df_man.groupby('time_temp').size()

# CAN POTENTIALLY DO THIS FOR JUST THE PROTEST DATES
# Create a list of the hourly count of tweets over the entire date range
hourly_count = []
freq = 0
for time, frequency in zip(volume_time.index, volume_time):
    freq += frequency
    if time.minute == 59:
        hourly_count.append(freq)
        freq = 0

# Create a simple list of date time objects for every hour
hour_list = []
for hour in range(24):
    hour_list.append(dt.time(hour, 0, 0))
    
fig, ax = plt.subplots(figsize=(18, 6))    

ax.plot(hour_list, hourly_count, 'royalblue')
ax.set_xlabel("Time of day")
ax.set_ylabel("Tweet Frequency (by hour)")
ax.set_title("Tweet frequency across different times of the day")
ax.set_facecolor('whitesmoke')
ax.set_label('Minutely frequency')


ax2 = ax.twinx()
ax2.plot(volume_time, 'g')
ax2.set_ylabel('Tweet Frequency (by minute)')
ax2.set_xticks([dt.time(hour, 0, 0) for hour in range(24)])

green_patch = mpatches.Patch(color='g', label='Minutely frequency')
r_blue_patch = mpatches.Patch(color='royalblue', label='Hourly frequency')
plt.legend(handles=[r_blue_patch, green_patch], loc = 'upper left')

plt.show()

# Delete these temporary data frames and series - they take up memory and can be created
# again if required

# %% [markdown]
# The plot above illustrates hourly (left y-axis) and minutely (right y-axis) tweet volume. It can be seen that the majority of protests occurred around midday. The obvious spike in Twitter activity during this time strenghtens the claim that protests are heavily linked to Twitter activity.

# %%
# Plot tweet volume by engagement type for core data

engage = df_man.groupby('time_temp')['replies', 'retweets', 'favorites'].sum()


# bins = range(24*60+1)
labs = ['Replies', 'Retweets', 'Favorites']
plt.figure(figsize=(18,6))
plt.stackplot(engage.index, engage['replies'], engage['retweets'], engage['favorites'], 
              labels = labs, colors = ['blue', 'orangered', 'green'])
plt.legend(fontsize = 12)
plt.xticks(3600*np.arange(0, 26, 2), ('0:00', '2:00', '4:00', '6:00', '8:00', 
                                      '10:00', '12:00', '14:00', '16:00', 
                                      '18:00', '20:00', '22:00', '24:00'))
plt.xlabel('Time of day')
plt.ylabel('Engagement frequency')
plt.title('Engagement type proportions for #FeesMustFall data')

# Plot zoomed figure
engage_zoom = engage[2*60:2*60+30]
sub_axes = plt.axes([.185, .55, .25, .25]) # location on original graph
sub_axes.stackplot(engage_zoom.index, engage_zoom['replies'], engage_zoom['retweets'], 
              engage_zoom['favorites'], labels = labs, colors = ['blue', 'orangered', 'green'])
sub_axes.set_xticks([dt.time(2, 5*minute, 0) for minute in range(7)])
sub_axes.set_xlabel('Time of day')
sub_axes.set_ylabel('Engagement frequency')
# plt.xlim([0, dt.time(6,0,0)])

plt.show()

# Memory is fairly full - delete these dataframes to improve runtime
del df_man
del volume
del volume_df
del scatter_df

# %% [markdown]
# The above plot looks at tweet by analysing the split between likes, replies and retweets per tweet. _Replies_ are a form of __active__ engagement where the user is looking to engage in discussion whereas _likes and retweets_ function as a means to __spread a message__ or express agreement with the tweet in question.
#
# The plot makes clear that #FeesMustFall related tweets are predominantly engaged via retweets reinforcing the active nature of the movement. The zoomed plot in the top left corner demonstrates that this trend holds, _even_ at low engagement frequency hours of the day.
#
# We proceed to compare the above plot to benchmark data to ascertain whether this trend is specific to the #FeesMustFall movement.

# %%
# Plot tweet volume by engagement type for benchmark data

# Remove seconds - allows for better plot visualisation
df_rnd['created_at'] = df_rnd['created_at'].dt.floor('T') 
df_rnd['time_temp'] = [i.time() for i in df_rnd['created_at']]
rnd_tweets = df_rnd.groupby('time_temp')['retweets', 'favorites'].sum()
# Group the stackplot data by hour as a result of the large fluctuation in the minutely data
rnd_tweets['index'] = rnd_tweets.index
rnd_tweets['hour'] = rnd_tweets['index'].apply(lambda x: x.hour)
rnd_tweets = rnd_tweets.groupby('hour')['retweets', 'favorites'].sum()
rnd_tweets

rnd_labs = ['Retweets', 'Favorites']
plt.figure(figsize=(18,6))
plt.stackplot(rnd_tweets.index, rnd_tweets['retweets'], 
              rnd_tweets['favorites'], labels = rnd_labs,
             colors = ['orangered', 'green'])

#FIX THIS 24 HOUR GRAPH PROBLEM - you've used 0.958 to fix problem as a hack  
plt.xticks(0.958*np.arange(0, 26, 2), ('0:00', '2:00', '4:00', '6:00', '8:00', 
                                      '10:00', '12:00', '14:00', '16:00', 
                                      '18:00', '20:00', '22:00', '24:00'))

plt.legend()
plt.xlabel('Time of day')
plt.ylabel('Engagement frequency')
plt.title('Engagement type proportions for benchmark data')

plt.show()

# %% [markdown]
# Data in the plot above is taken from a sample of users who actively tweeted about #FeesMustFall. However, the data in question involves these users' tweets from 6 months after the protests until 2020/01/05 ensuring the majority of these tweets are not related to #FeesMustFall. This allows for meaningful comparison. Unfortunately, one requires a premium API subscription to access the reply count [(evidenced here)](https://stackoverflow.com/questions/47851662/reply-count-attribute-missing-from-tweet-object) and so replies are excluded as a metric in this plot.
#
# Retweets form a much smaller proportion of engagement in the plot above relative to #FeesMustFall engagement. This suggests the retweet proportion of engagement on the #FeesMustFall topic is abnormally high. This reinforces the notion that the movement was primarily concerned with action, rather than discussion.

# %% [markdown]
# #### Summary of findings
# Anaylsis in this section suggests Twitter activity was linked to protest action. This is evidenced by:
# 1. Higher activity on protest dates
# 2. Higher activity during times when protests occur
# 3. Retweets (used to mobilise protestors) being the primary form of engagement

# %% [markdown]
# ### Objective 2: Identifying key participants and clusters
# ####  Network analysis
#
# This notebook proceeds to analyse interactions and influential users and communities by analysing the Twitter data. Using the ntwrk data, the following key statistics within the network are calculated:
# 1. __Total nodes and egdes:__ in the network to give an idea of the scope of users and interconnectedness between them
# 2. __Information on the degree of notable nodes:__ the degree refers to the number of edges a particular node has
# 3. __Number of connected components in the graph:__ this refers to the number of subgraphs in which a path exists between every node
# 4. __Largest subgraph:__ this notebook focuses on analysing the largest connected subgraph
# 5. __Clustering and transitivity:__ these are both measures of the degree to which nodes tend to cluster together and hence are useful for determining whether users create tightly-knit groups. Clustering places high emphasis on low-degree nodes whereas transitivity emphasises the lower degree nodes. More information on these measures can be found [here](https://en.wikipedia.org/wiki/Clustering_coefficient) ADD IN ANALYSIS: The clustering co-efficient is larger suggesting that there is some tendency for the high degree nodes to form small clusters.
#
# To best visualise the network structure, the network of the largest connected subgraph is depicted. This gives insight into the interactions between the most active users during the #FeesMustFall campaign.

# %%
# Perform network analysis on #FeesMustFall users
 
# Create graph by adding edges from ntwrk
G = nx.Graph()

for node_1, node_2 in ntwrk:
    G.add_edge(node_1, node_2, weight=1)
    
print("The graph has %d nodes with %d edges" % (nx.number_of_nodes(G), nx.number_of_edges(G)))
degrees = [val for (node, val) in G.degree()]
# The degree of a node is how many nodes it is connected to
# Max degree of graph is how many connections the node with the most connections has
# CREATE A TABLE IN PYTHON WITH THE INFO BELOW
print("Max degree of graph is", np.max(degrees))   
print("Min degree of graph is", np.min(degrees))
print(f"The average degree of the nodes in the Graph is {np.mean(degrees):.1f}")  
print(f"The most frequent degree of the nodes found in the Graph is {stats.mode(degrees)[0][0]}")
print(nx.is_connected(G)) # graph isn't connected
print(nx.number_connected_components(G), "connected components")
largest_subgraph = max(nx.connected_component_subgraphs(G), key=len)
print(f"There are {largest_subgraph.number_of_nodes()} nodes and {largest_subgraph.number_of_edges()} \
edges present in the largest component of the Graph")

print(f"The average clustering coefficient is {nx.average_clustering(largest_subgraph)} in the largest subgraph")
print(f"The transitivity of the largest subgraph is {nx.transitivity(largest_subgraph)}")

# Block of code below took 4 hours to run 
print(f"The diameter of the Graph is {nx.diameter(largest_subgraph)}")
print(f"The average distance between any two nodes is {nx.average_shortest_path_length(largest_subgraph):.2f}")
# The diameter of the Graph is 18
# The average distance between any two nodes is 4.66

graph_centrality = nx.degree_centrality(largest_subgraph)
max_de = max(graph_centrality.items(), key=itemgetter(1))
graph_closeness = nx.closeness_centrality(largest_subgraph)
max_clo = max(graph_closeness.items(), key=itemgetter(1))
graph_betweenness = nx.betweenness_centrality(largest_subgraph, normalized=True, endpoints=False)
max_bet = max(graph_betweenness.items(), key=itemgetter(1))
print(f"the node with id {max_de[0]} has a degree centrality of {max_de[1]:.2f} which is the maximum of the Graph")
print(f"the node with id {max_clo[0]} has a closeness centrality of {max_clo[1]:.2f} which is the maximum of the Graph")
print(f"the node with id {max_bet[0]} has a betweenness centrality of {max_bet[1]:.2f} which is the maximum of the Graph")
# the node with id eNCA has a degree centrality of 0.05 which is the maximum of the Graph
# the node with id eNCA has a closeness centrality of 0.35 which is the maximum of the Graph
# the node with id eNCA has a betweenness centrality of 0.16 which is the maximum of the Graph
# Took 24 hours to run above code

# %%
# Position nodes using Fruchterman-Reingold force-directed algorithm.
# Finding the centrality measures and plotting the network took approx 11 hours

node_and_degree = largest_subgraph.degree()
colors_central_node = ['red']
central_nodes = ['eNCA']

pos = nx.spring_layout(largest_subgraph, k=0.05)
fig = plt.figure(figsize = (20,20))
nx.draw(largest_subgraph, pos=pos, node_color=range(largest_subgraph.number_of_nodes()), 
        cmap=plt.cm.PiYG, edge_color="black", linewidths=0.3, node_size=60, alpha=0.6, 
        with_labels=False)
nx.draw_networkx_nodes(largest_subgraph, pos=pos, nodelist=central_nodes, node_size=300, 
                       node_color=colors_central_node)

fig.savefig("images/full_network.png", bbox_inches='tight', dpi=600)

Image(filename="images/full_network.png") 

# NBNBNB CONSIDER ADDING NODES THAT ARE USERNAMES THAT HAVE INTERACTED WITH NOBODY BUT HAVE MANY FOLLOWERS
# AND HAVE TWEETED

# %%
with open('pickle_files/updated_follow_dict.pickle', 'rb') as handle:
    follow_dict = pickle.load(handle)
pop_ntwrk = []
pop_edge_ignored = []
for node_1, node_2 in ntwrk:
    try:
        if follow_dict[node_1]>2000000 or follow_dict[node_2]>2000000:
            pop_ntwrk.append([node1, node2])
    except:
        pop_users_ignored.append([[node1, node2]])
          
# EXTRA CHECK:
print(len(pop_ntwrk)+len(pop_users_ignored))# SHOULD EQUAL LEN(NTWRK)
# Out:
# ['informer_sa', 'SkhumbuzoTuswa']
# ['WitsUniversity', 'SediButhez']
# ['DjDcoolDiamond', 'colleges']
# ['DjDcoolDiamond', 'WITS']
# ['MandisaTshuta', 'Ncepsi']
# ['LwaziPakade', 'SthembileCel']
# ['Cde_Xolani', 'UPSRC_']
# ['Cde_Xolani', 'StelSRc']
# ['WitsSRC', 'KeMalesela']
# ['KeMalesela', 'Wits_ARC']
# ['Cde_Xolani', 'WitsUniversity']
# ['Cde_Xolani', 'UPTuks']
# ['DASONMMU', 'Tee_Sitolotolo']
# ['DAYoungLeaders', 'Tee_Sitolotolo']
# ['SlieAfrica', 'palesamorudu']
# ['Mngxitama', 'BIack1stLand1st']
# ['DonaldMahlangu', 'MyANC_']
# ['AliciaJali', 'HonourableHloni']
# ['RhodesMustfall', 'Harold_Ferwood']
# ['karabzy', 'Pretoria']
# ['The_Real_Bafana', 'maths00001']
# ['RichardBruneSA', 'MyANC_']
# ['mamzmolepo', 'gigaba__']
# ['LufefeMalala', 'gigaba__']
# ['Siya_Njica', 'gigaba__']
# ['kamva_somdyala', 'IngeBeukes13']
# ['kamva_somdyala', 'MizzFumi_K']
# ['Mphok_Stofile', 'BladeNzimandeMP']
# ['eNCA', 'RoscoeJacobs']
# ['RoscoeJacobs', 'ANN7tv']
# ['uManqobaM', 'UCTCollegeOfAcc']
# ['PGDAStudent2015', 'uManqobaM']
# ['jaarsveld_C', 'DASOTuks']
# ['HerSlayship', 'mmabatho_t']
# ['Julius_S_Malema', 'mamongato']
# ['EconFreedomZA', 'mamongato']
# ['unathimsengana', 'KhanyoLushaba']
# ['phaphamamlfm', 'frankhlabangwan']
# ['GentleForev', 'MalacosteDaReal']
# ['Rhodes', 'dubheza']
# ['mzaykesman', 'PresidencyZA']
# ['mzaykesman', 'DBE_SA']
# ['imsimzissah', 'UPTuks']
# ['fanele_fs', 'MyANC_']
# ['WitsUniversity', 'Anele_Nzimande']
# ['MorolongZA', 'Lesufi']
# ['MbobyP', 'Le_Rots']
# ['GoitseMoroka', 'MyANC_']
# ['mzwa_i', 'WitsSRC']
# ['Lefa_M_', 'IamRenolda']
# ['AFRICAN_JOURNO', 'Powerfm987pic']
# ['eNCA', 'AFRICAN_JOURNO']
# ['AFRICAN_JOURNO', 'PresidencyZA']
# ['ewnupdatespic', 'AFRICAN_JOURNO']
# ['TheeAlphaBro', 'palesamorudu']
# ['TheeAlphaBro', 'TeaJay_001']
# ['IamRenolda', 'TshephoSes']
# ['benjamin_sa', 'MyANC_']
# ['phuti7', 'palesamorudu']
# ['OhFvcc', 'vuyo95_']
# ['NJ_Khathi', 'SAPresident']
# ['CapeTimesSApic', 'MojoIOL']
# ['eNCA', 'Kgotsi_Chikane']
# ['SABCNewsOnlinepic', 'Kgotsi_Chikane']
# ['PartlyFiltered', 'mmabatho_t']
# ['TheCapeArguspic', 'MojoIOL']
# ['BecauseJulz', 'Thato_Or_Totem']
# ['Wits', 'Pol_Con_Mandela']
# ['Gcwanin_Omhle', 'EconFreedomZA']
# ['PrezSankara', 'WitsSRC']
# ['PrezSankara', 'StelSRc']
# ['ashleighfurlong', 'GroundUp_Newspic']
# ['raediology', 'Pontsho_Pilane']
# ['raediology', 'thembi_lewis']
# ['WitsSRC', 'Urban_Xhosa']
# ['Artii_M', 'eNCApic']
# ['Shantie_Kay', 'MaGillieey']
# ['UCT', 'MissMadiba']
# ['SpheleleSpeaks', 'SpheDludla']
# ['Nxibelo_S', 'zimkitag']
# ['usayed1995', 'UCT']
# ['Notty_Mnguni', 'tokelofako']
# ['eNCA', 'Mavhy_']
# ['zsszonyane', 'KOUSY_']
# ['', 'zsszonyane']
# ['GoitseKonopi', 'saramsalem']
# ['mojoIOL', 'insulter1']
# ['NeliMsomi', 'YouTube']
# ['SABCNewsroom', 'ReneVest_']
# ['SABCNewsroom', 'lindosimelane']
# ['TheAgenda_SABC', 'SABCNewsroom']
# ['SABCNewsroom', 'AnnineD']
# ['ASAP_Yayah', 'SABCNewsroom']
# ['loyisogola', 'Sanza_Mthombeni']
# ['DHET4', 'yokufunda']
# ['MutatedPear', 'Reagoikanya']
# ['VillageShrink', 'Reagoikanya']
# ['Siya_King', 'Kay_Angel']
# ['JasonDerulo', 'AfrikanJeanyus']
# ['WitsSRC', 'lesliecnr']
# ['phuti7', 'justiceleshilo']
# ['WitsSRC', '_nOmBz_']
# ['raediology', 'thulilegamedze']
# ['KingKhanyi_', 'KneoMokgopa']
# ['Isaac_Moselane', 'tanyaradzwa__']
# ['Thato_Smal', 'Yandii__']
# ['gmail', 'KingKhanyi_']
# ['Naked_Dj', 'CarolynNosipho']
# ['CarolynNosipho', 'bonang_m']
# ['polepolepress', 'llemaoana1']
# ['UCTStudents', 'Mangi_G07']
# ['EconFreedomZA', 'THUSO_E']
# ['ronin136', 'grassroots']
# ['Legendary_Thato', '_YaNdii_']
# ['mzivelapi', 'Elitsha2014pic']
# ['getting_smarter', 'babeswokublokwa']
# ['MbalulaFikile', 'Tweeririe']
# ['serendipretti', 'Kay_Angel']
# ['GwedeUncle', 'mashiyanef']
# ['BladeNzimandeMP', 'mashiyanef']
# ['SharesandShares', 'Mick_Fanning']
# ['NMMU4U', '101Cherise']
# ['NWUPUK', '101Cherise']
# ['UKZN', '101Cherise']
# ['generalpope', 'NSFAS1']
# ['SihleSays', 'bernwolhuter']
# ['thedailyvox', 'Pontsho_Pilane']
# ['Rhodes', 'georgiaflax']
# ['BBCAfrica', 'KsKhathi']
# ['Sihle_Mahogany', 'CurtisNZuZA']
# ['GermanyEdu', 'sizons']
# ['iamkevxn', 'serendipretti']
# ['loyisogola', 'Consolation46']
# ['SeasonTravelerZ', 'MyANC_']
# ['generalpope', 'ANN7tv']
# ['CiciRussell', 'ANN7']
# ['Queen_Mogale', 'Not_JahLady']
# ['UPTuks', '_NkushM']
# ['CiciRussell', 'ANN7tv']
# ['will_dhliwayo', 'Anele_Nzimande']
# ['UCTJustKiddingpic', 'KhWeZiMoTo']
# ['GallantGhalib', 'r2kcampaignpic']
# ['loyisogola', 'Sboh_L']
# ['ProfJNMoyo', 'wilfmoyo']
# ['GdTonga', 'highleesirlousy']
# ['eNCA', 'Kylio_Leaver']
# ['CurateZAR', 'SirMashiane_K']
# ['Gcwanin_Omhle', 'BladeNzimandeMP']
# ['WitsUniversity', 'Jarred_McC']
# ['BBCAfrica', 'Afripopmag']
# ['shawnroos', 'waynethebrain']
# ['ZareefSMB', 'News24']
# ['eNCA', 'khosimka']
# ['LindokuhleZondi', 'NdumisoIgama']
# ['Thamsanqa_Pooe', 'Busisiwe_G']
# ['eNCa', 'khosimka']
# ['Eusebuis', 'khosimka']
# ['LThipa', 'AzolaMboniswa']
# ['thedailyvox', 'thembi_lewis']
# ['WitsUniversity', 'TheRealMpho']
# ['dasoufh', 'MyANC_']
# ['kagisodoc', 'LuloCafe']
# ['AlJazeerapic', 'Jarred_McC']
# ['BostonMediaH', 'Bosslady22d']
# ['loyisogola', 'motilaa']
# ['NgwatoMokone', 'imramushu']
# ['EconFreedomZA', 'Bhungane3003']
# ['Julius_S_Malema', 'Bhungane3003']
# ['LoyisoGola', 'PhilMphela']
# ['IamMartin__', 'Swanktified']
# ['futbolprof', 'RanjeniM']
# ['Julius_S_Malema', 'Th3_Official_TP']
# ['4everSiyapic', 'ewnreporter']
# ['DHET4', 'KokoNdhlovu']
# ['Julius_S_Malema', 'NJ_Khathi']
# ['lesterkk', 'Artii_M']
# ['eNCA', 'Artii_M']
# ['Artii_M', 'andrewTbarnes']
# ['WitsSRC', 'kiing__jae']
# ['Mgeepa', 'Be_A_stevie']
# ['nna_gape', 'NWUMafikeng']
# ['Julius_S_Malema', 'herby_tshepo1']
# ['WitsUniversity', 'UyandaMabece']
# ['Mzi_lankatha', 'pookiportia']
# ['BladeNzimandeMP', 'FunekaSibande']
# ['uptuks', 'Paledian']
# ['walkerworldwide', 'CapeTimesSApic']
# ['Sonkoerantpic', 'mfazwe']
# ['sibacooo', 'Anele_Nzimande']
# ['WitsSRC', 'Jarred_McC']
# ['Nd1y1Tribal_Qha', 'I_A_MRoyalty']
# ['Nd1y1Tribal_Qha', 'Pontsho_Pilane']
# ['ZandiMZK', '_NaomieChoC']
# ['JuniorFrisco', 'eNCA']
# ['illumi_Nate01', 'kfc']
# ['Thato_Smal', 'Pronart_11']
# ['RethinkWits', 'Ulo_Mkat']
# ['UMAR_FAROUK7', 'LoyisoGola']
# ['Ulo_Mkat', 'Busisiwe_G']
# ['Tsheogal', 'PaBiiEe']
# ['DivasANC', 'Siyabonga_Hani']
# ['ii_naome', 'pookiportia']
# ['Lwazi_Somya', 'Mbatha10']
# ['KrilaGP', 'Mbatha10']
# ['ZuluJoziGuy', 'PaBiiEe']
# ['AyeshaR_786', 'Pontsho_Pilane']
# ['Julius_S_Malema', 'SakhileMalo']
# ['WitsSRC', 'SakhileMalo']
# ['WitsSRC', 'Nqontja']
# ['WitsSRC', 'rJ30010']
# ['Zienhleh', 'Black_Aurum']
# ['Julius_S_Malema', 'Mlungisi_prince']
# ['kasiyouth', 'SascoUjApk']
# ['uQuestionaire', 'mgfeed']
# ['thedailyvoxpic', 'pontsho_pilane']
# ['_KageVersal_', 'debzarad']
# ['DinoSpolidoro', 'Lu_vuyolwethu']
# ['edrishlongwane', 'Sentletse']
# ['_The7thDay', 'WitsSRC']
# ['_The7thDay', 'WitsUniversity']
# ['varsitynewspic', 'YogiShobz']
# ['Pontsho_Pilane', 'SAYoungLion']
# ['danwibg', 'eNCA']
# ['Tee_Sitolotolo', 'lmtyobile']
# ['t_mpondo', 'News24']
# ['JohanFourieZA', 'TC_Africa']
# ['altergothen', 'MinNzimandeDHET']
# ['altergothen', 'Julius_S_Malema']
# ['EmmahMabye', 'LethaboTumelo']
# ['altergothen', 'BladeNzimandeMP']
# ['BladeNzimandeMP', 'Angel_iOnline']
# ['eNCA', 'LirandzuThemba']
# ['KabwelaC', 'jozisoul']
# ['hayesstw', 'wordpressdotcom']
# ['__Wanjiru__', 'AJEnglish']
# ['priscanall', 'ChefJoeBandler']
# ['thedailyvox', 'Raediology']
# ['TebohoLiloro', 'twasagirl']
# ['MusaMoousse', 'Maureen_MP']
# ['francheskatnc', 'Caspar_Lee']
# ['WitsUniversity', 'thulethozwane']
# ['MyANC_', 'that_guy_sfi']
# ['ANC_KKhoza', 'that_guy_sfi']
# ['theblackbushy', 'eNCApic']
# ['NoncebaMhlauli', 'SASCO_Jikelelepic']
# ['SirLadyKathryn', 'SAPresident']
# ['BladeNzimandeMP', 'SirLadyKathryn']
# ['TheRealestRoger', 'MotlokwaP']
# ['BD_Africa', 'dira_m']
# ['llekoc', 'Maneer_Ronald']
# ['llekoc', 'MotlokwaP']
# ['Don_Makgaila', 'Caspar_Lee']
# ['becsplanbpic', 'TaxMeIfYouCanSA']
# ['Pontsho_Pilane', 'ThickLeeyonce']
# ['jasparxjim', 'Caspar_Lee']
# ['llekoc', 'MyANC_']
# ['Donaldphejane', 'AdamHabib']
# ['RasetlolaT', 'fikilembalula']
# ['coxmitchell', 'RaahilSain']
# ['khayakazikulaa', 'OnlyGirl_Mpumi']
# ['Julius_S_Malema', 'Matseleng_Leon']
# ['AbortedNews', 'WOOLWORTHS_SA']
# ['BladeNzimandeMP', 'KaraboMasilela']
# ['thulethozwane', 'AdHabb']
# ['artindira', 'SihleDLK']
# ['eNCA', 'lenyarosello']
# ['eNCApic', 'lenyarosello']
# ['Keneilwe_Sebola', 'DASO']
# ['Powerfm987', 'DASO']
# ['Wits', 'KatekaniNamane']
# ['Caspar_Lee', 'NigerianOSCAR']
# ['eNCA', 'margiedgander']
# ['maso2kwataSA', 'EFFSC_UFH']
# ['UJAPK_SRC', 'NtshemboRik']
# ['BladeNzimandeMP', 'margiedgander']
# ['SchoolsureSa', 'WitsFeesFall']
# ['WitsFeesFall', 'School_Sure']
# ['MceboDlamini2', 'maso2kwataSA']
# ['Seabelo_M', 'Kay_OhYeah']
# ['sentlhane', 'Kay_OhYeah']
# ['timusician', 'SAPresident']
# ['Be_A_stevie', 'ThyOtis']
# ['gumede783', 'maths00001']
# ['MoBlaq7', 'maths00001']
# ['AdHabb', 'Malabulabu945']
# ['EconFreedomZA', 'marrakurru']
# ['eNCA', 'Bam76Lulu']
# ['Computicket', 'TheFugard']
# ['loyisogola', 'Moses_Nku']
# ['AmandlaMobi', 'eNCApic']
# ['WitsUniversity', 'Wendy_Mothata']
# ['Wendy_Mothata', 'UPTuks']
# ['BladeNzimandeMP', 'Wendy_Mothata']
# ['Be_A_stevie', 'MarvelHlungwani']
# ['Magondzoni', 'Caspar_Lee']
# ['motapes', 'owen']
# ['motapes', 'putso']
# ['eNCA', 'NtshemboRik']
# ['Sthathi', 'Maneer_Ronald']
# ['YashPaddy', 'eNCA']
# ['zsszonyane', 'safmpmlive']
# ['prineng', 'Sir_KattBortes']
# ['Phil8703', 'TshabalalaSL']
# ['_Kagiiso', 'Be_A_stevie']
# ['ClxssicsOnly', 'MyANC_']
# ['Sentletse', 'ThusiSabelo']
# ['Phil8703', 'ThatGuy4D']
# ['MsDipsT', 'Sentletse']
# ['safmpmlive', 'TsepisoMakwetla']
# ['LeboLytz', 'DeepFriedManpic']
# ['rox_jos', 'Lesufi']
# ['YashPaddy', 'lesterkk']
# ['YashPaddy', 'dstv']
# ['AmandlaMobi', 'vuyolwetu_']
# ['Mr_C_hlangu', 'Sentletse']
# ['SAPresident', 'RealMandisi']
# ['_Memorie_', 'Sentletse']
# ['eNCA', 'AdHabb']
# ['ThembiMrototo', 'TazEssop14']
# ['addifferent', 'WamuwiM']
# ['Buhle_Nkonki', 'faro_ntsinde']
# ['EconFreedomZA', 'LlewellynLamber']
# ['LlewellynLamber', 'MyANC_']
# ['lekhooe10', 'your']
# ['dayamond_lama', 'Mahumz']
# ['Pontsho_Pilane', 'Mmabatho0']
# ['KamilHess24', 'Caspar_Lee']
# ['YashPaddy', 'AdHabb']
# ['YashPaddy', 'duduramela']
# ['eNCA', 'duduramela']
# ['eNCA', 'dstv']
# ['safmpmlive', 'EliasChinemore']
# ['eNCA', 'Tayto_zm']
# ['MyANC_', 'AfrikanJeanyus']
# ['thedailyvox', 'AdHabb']
# ['DevaLee', 'MyANC_']
# ['diannehawker', 'eNCA']
# ['Je_suis_sanity', '12']
# ['ThokozaniM_21', 'Sentletse']
# ['Wizba', 'Sentletse']
# ['eNCA', 'MishEverdin']
# ['eNCA', 'kgomotso_mos']
# ['lushdreamer', 'Disruptia']
# ['TazEssop14', 'ThusiSabelo']
# ['EsethuHasane', 'Sthathi']
# ['AdHabb', 'margiedgander']
# ['eNCA', 'bb_mhat']
# ['orla_barry', 'matubapressure']
# ['diannehawker', 'duduramela']
# ['TebohoLiloro', 'enca']
# ['eNCA', 'Ntemz07']
# ['crakeras', 'iqbusiness']
# ['crakeras', 'eNCA']
# ['eNCA', 'uAthi_N']
# ['eNCA', 'Leborams']
# ['Pontsho_Pilane', 'DepressiaDube']
# ['AdHabb', 'Leighratoh']
# ['eNCA', 'realMadumane']
# ['LuminateYourLyf', 'eNCA']
# ['LuminateYourLyf', 'AdHabb']
# ['News24', 'zimbo64']
# ['oliver_meth', 'MyANC_']
# ['oliver_meth', 'PresidencyZA']
# ['Nkgau_M', 'News24']
# ['Vahiza', 'eNCA']
# ['Vahiza', 'AdHabb']
# ['Vahiza', 'duduramela']
# ['Vahiza', 'dstv']
# ['gama273', 'AdHabb']
# ['gama273', 'duduramela']
# ['gama273', 'dstv']
# ['zimazisa', 'eNCA']
# ['priscanall', 'jazzphotosmbs']
# ['247_Rebel', 'Schillo_15']
# ['lesterkk', 'eNCA']
# ['safmpmlive', 'sibongukwanda']
# ['Allan_2801', 'Julius_S_Malema']
# ['JLephalala', 'News24']
# ['IamMzisi', 'ClxssicsOnly']
# ['priscanall', 'studentsex8']
# ['UFH', 'SixotoWR']
# ['eNCA', 'Girly_Kepadisa']
# ['MandlaMagidela', 'News24']
# ['hustlernature', 'tacobell']
# ['khotsoDM', 'MyANC_']
# ['ferialhafajee', 'AfrikaSebezo']
# ['AfrikaSebezo', 'Mothekgi_Mp']
# ['NorthWestZA', 'eNCA']
# ['WWE', 'JAYMILL25']
# ['WWEUniverse', 'JAYMILL25']
# ['FirstTakeSA', 'wits']
# ['FirstTakeSA', 'AdHabb']
# ['SizweMW', 'AfrikaSebezo']
# ['raediology', 'yaseen_hassim']
# ['NomalangaSA', '_Babazile']
# ['SivuMpic', '_Babazile']
# ['safmpmlive', 'IamSiphoChule']
# ['StudentSpaza', 'Pontsho_Pilane']
# ['Lesufi', 'JacquiThePoet']
# ['LuthoSokudela', 'MyANC_']
# ['UJAPK_SRC', 'TheNudeAdvocate']
# ['justiceMalala', '1BraTabs']
# ['realwizkaliaa', 'GMUStudentPower']
# ['IanPolka', 'aycawe']
# ['Thu_ways', 'Sentletse']
# ['THEQUEEN', 'OzMosesJo']
# ['OzMosesJo', 'THEBBC']
# ['OzMosesJo', 'THETAXMAN']
# ['thembi_lewis', 'JacquiThePoet']
# ['StuBuSA', 'JacquiThePoet']
# ['uMamaWeVibe', 'Wits']
# ['Chabz_Classic', '__Tumelo']
# ['GwalaX', 'leloe_m']
# ['Ndoomi_Makh', 'Msizi_001']
# ['News24', 'dani_w121']
# ['WitsUniversity', 'Radio702']
# ['Radio702', 'AdHabb']
# ['terencematera', 'lesterkk']
# ['Computicket', 'CapeTheatre']
# ['EconFreedomZA', 'rendiematthew']
# ['Sentletse', 'SelfieRunnerZA']
# ['WitsSRC', 'uMamaWeVibe']
# ['CamModisane', 'bfutsh']
# ['priscanall', 'ironwarriorathl']
# ['IA_Library', 'StreetTweeth']
# ['Brigda1VRadio', 'eNCA']
# ['Rudolf_koks', 'cornetmamabolo']
# ['WitsUniversity', 'That_RICHIEguy']
# ['AdHabb', 'That_RICHIEguy']
# ['priscanall', 'Stockafied']
# ['YusufOmarSA', 'eNCA']
# ['Paulinebritney', 'MyANC_']
# ['ItsMishMash', 'KidFury']
# ['WitsUniversity', 'Hatia_M']
# ['AdHabb', 'Hatia_M']
# ['erik_deridder', 'SizweMW']
# ['RadioLeadAfrica', '']
# ['XhosaTribe', 'chrisbrown']
# ['EconFreedomZA', 'XhosaTribe']
# ['eNCA', 'TROMASIBI']
# ['RISEfm943', 'MilaMfundo']
# ['sammytlhapi', 'PresidencyZA']
# ['AdHabb', 'sammytlhapi']
# ['eNCA', 'lelowhatsgood']
# ['hamboneZA', 'SAPresident']
# ['4DownGG', 'BrewAndGame']
# ['Gert_LeNinja', 'Be_A_stevie']
# ['ZamaDube', 'Tebza808']
# ['AbzHudsonpic', 'TheCitizen_News']
# ['ragingpoet', 'Angelinah_M']
# ['benjamin_sa', 'SAPresident']
# ['JabuMoroko', 'RanjeniM']
# ['Matzie127', 'UPTuks']
# ['eNCA', 'CollenThwala21']
# ['lesterkk', 'CollenThwala21']
# ['priscanall', 'Hardebaryor3']
# ['TheKimmish', 'djkevking']
# ['ZwelinzimaVavi', 'labodiba']
# ['VuyaniPambo', 'ZaahiraYelena']
# ['EVRTHNGSTYLES_', 'kopano_za']
# ['mikeiz7', 'yusufCassim']
# ['BabyAlphabets', 'BabyAlphabetspic']
# ['WitsSRC', 'JaninevWyk']
# ['JaninevWyk', 'AdHabb']
# ['beat_traffik', 'Gidi_Traffic']
# ['beat_traffik', 'TrafficChiefNG']
# ['beat_traffik', 'Areaaa_']
# ['beat_traffik', 'InsideMainland']
# ['Lwazi_Somyapic', 'Mbatha10']
# ['Nhlonipho__', 'eNCA']
# ['Nhlonipho__', 'News24']
# ['doccfada', 'MyANC_']
# ['BBC', 'BusinessinAfric']
# ['ironfistAsh', 'JMPDSafety']
# ['NE_Tribune', 'JMPDSafety']
# ['zee_khumalo', 'Noks_Khwela']
# ['NontohGumede', 'Mokgethwa_Mpic']
# ['eNCA', 'justicemalala']
# ['eNCA', 'JohnMphatsoe']
# ['ANN7tv', 'JohnMphatsoe']
# ['Computicket', 'SATheatre']
# ['PresidencyZA', 'Jerrys_Berry']
# ['Bhungane3003', 'MyANC_']
# ['Ondi_S', 'artindira']
# ['YouTube', 'Shadrak_Sithole']
# ['karabzy', 'Corner']
# ['raediology', 'Mngxitama']
# ['MandyKinZz', 'LwaziPakade']
# ['KwenaMabye', 'Pontsho_Pilane']
# ['Noooooooonie', 'eNCA']
# ['JabulaniMyeza', '_Mpondokazi']
# ['WitsSRC', 'TheVoiceArtist']
# ['WitsSRC', 'theafricanchild']
# ['theafricanchild', 'UCT_SRCpic']
# ['GrahamstownSA', 'SusanMaclennan2']
# ['kamoFBK', 'eNCA']
# ['kamoFBK', 'yuth']
# ['EvansMathibe', 'eNCA']
# ['eNCA', 'Tioranta']
# ['WitsSRC', 'not_siwelele']
# ['VuyaniMG', 'NanaRapz']
# ['sir_McLovin89', 'palesamorudu']
# ['lzn94', 'MakhwaB']
# ['StianMouton', 'TristillSA']
# ['Tshego_Ubisi', 'BradleyChauke']
# ['UPTuks', 'f_r_e_d_k']
# ['RhodesSRCpic', 'theafricanchild']
# ['MyANC_', 'LeYoung_D']
# ['snethyg001', 'thezulugoddess1']
# ['officialDUTSRC', 'TheVoiceArtist']
# ['Wsrc_UKZN', 'TheVoiceArtist']
# ['theafricanchild', 'officialDUTSRC']
# ['theafricanchild', 'Wsrc_UKZN']
# ['ClintonSamps', 'snethyg001']
# ['Th4bil3ng', 'KaySexwale']
# ['nytimes', 'Th4bil3ng']
# ['ANN7tv', 'SNNreporter']
# ['Ulo_Mkat', 'TheVoiceArtist']
# ['theafricanchild', 'Ulo_Mkat']
# ['bantu_dj', 'ANN7tv']
# ['futbolprof', 'lesterkk']
# ['WitsFeesFall', 'OhGodItsSK']
# ['eNCApic', 'twieterazzi']
# ['MyANC_', 'tshepang']
# ['BuhleNkonki', 'LuzukoBuku']
# ['BuhleNkonki', 'eNCA']
# ['DJ_MiloSA', 'highleesirlousy']
# ['ImTawanda', 'Anele_Nzimande']
# ['yfm', 'NolenceMashego']
# ['Alexfm891', 'sialeita']
# ['sialeita', 'slm_891']
# ['snethyg001', 'Hoodoo_priest']
# ['Mmotlana29', 'yfm']
# ['university', 'summerstone100']
# ['ANN7tv', 'twieterazzi']
# ['LlewellynLamber', 'MattBlackZA']
# ['palesamorudu', 'DrCamModisane']
# ['oprah', 'jtkeays']
# ['Pontsho_Pilane', 'sa_poptart']
# ['ALETTAHA', 'MyANC_']
# ['ntsikimazwai', 'nande_flint']
# ['mdlaneCrossrd', 'ALETTAHA']
# ['tpmotsoeneng', 'ALETTAHA']
# ['jtkeays', 'SAPresident']
# ['ANC_Midrand', 'MoketeBeletane']
# ['MrSoulful_X', 'ANN7tv']
# ['Malatjie_', 'Sentletse']
# ['WitsSRC', 'Skhumba07']
# ['MayaLagardien', 'RaymondSuttner']
# ['RobyKirk', 'LittleManKriel']
# ['NomMkhize1', 'TazEssop14']
# ['SRnwupuk', 'MSA_PUKKE']
# ['NWUPUK', 'MSA_PUKKE']
# ['jaihobabaki', 'settingsutra']
# ['Waseema_Lombard', 'Pontsho_Pilane']
# ['theseez', 'DreadSbu']
# ['Caspar_Lee', 'Emily_Sphiwe']
# ['YouTube', 'theblackbushy']
# ['CPUT', 'Dzubharisto']
# ['uct', 'loyisoqanya']
# ['vowfm', 'Ulo_Mkat']
# ['vowfm', 'WitsSRC']
# ['Ulo_Mkat', 'DjWiggaSA']
# ['WitsSRC', 'DjWiggaSA']
# ['MarvinMofficial', 'eNCA']
# ['Masechaba_L', 'khuli25']
# ['ShottaZee', 'MyANC_']
# ['DStv', 'Girly_Kepadisa']
# ['MarvinSomethng', 'Fihlela_A']
# ['Lebone133', 'Masechaba_L']
# ['rendiematthew', 'AdHabb']
# ['PowerFm', 'NosiphoKhulu']
# ['emjaykhumalo', 'Seano34']
# ['will_dhliwayo', 'BaitAlley']
# ['witsfeeswillfall', 'DjWiggaSA']
# ['eNCA', 'Bandiesel2']
# ['MbalulaFikile', 'iMatterOfFact']
# ['fdlangamandlapic', 'YusufOmarSA']
# ['BladeNzimandeMP', '786haso']
# ['AdHabb', 'PiloloNdlovu']
# ['elna_s', 'Vowfm']
# ['WitsMedSchool', 'GetDownAdam']
# ['DjokerNole', 'Nwankwo40423704']
# ['ImmacuM', 'pookiportia']
# ['eNCA', 'uMamaWeVibe']
# ['BGF013', 'MyANC_']
# ['sunnysidehobo1', 'sa_lottery']
# ['PresidencyZA', 'DumaPewa']
# ['MyANC_', 'Mokete_Motaung']
# ['Magano_B', 'Ant_vT']
# ['eNCA', 'Sikhululekile_']
# ['mashiyanef', 'MyANC_']
# ['eNCA', 'LebonaMoleli']
# ['tlsekopa', 'WitsSRCpic']
# ['PearlPillay', 'goitsekonopi']
# ['MCOOLUsox', 'CommonSeseBoB']
# ['CommonSeseBoB', 'MyANC_']
# ['eNCA', 'GoitseKonopi']
# ['AdriaanBArmy', 'GoitseKonopi']
# ['008joshluv', 'pic']
# ['GoitseKonopi', 'MikeMatlapeng']
# ['Azania', 'decolonialqueer']
# ['DKB20', 'GoitseKonopi']
# ['MpholoTeboho', 'IRAWAPost']
# ['shaunmbhiza', 'tsheponotchepo']
# ['Mamthug', 'EveeGolds']
# ['WitsSRC', 'ntusit']
# ['mashoko112', 'MyANC_']
# ['DHET4', 'mashoko112']
# ['mashoko112', 'ANN7tv']
# ['mbabalo', 'CommonSeseBoB']
# ['NandosSA', 'AlexanderSegall']
# ['DigitalBazaarSA', 'Neinei_Ngubs']
# ['misheckmunyai', 'ThandazaniM1']
# ['shehnazmunshi', 'WitsSRC']
# ['shehnazmunshi', 'WITSWSCpic']
# ['ThandoSiziba', 'missveebarbz']
# ['Miss_P_Mash', 'Pablo_Escobih']
# ['eNCA', 'yamalisa']
# ['sithembisonzima', 'Le_Rots']
# ['101sdrawkcab', 'Le_Rots']
# ['priscanall', 'dadofdivas']
# ['papa_action', 'XolisaM_']
# ['pigasuak', 'Stellenbosch']
# ['Ramoliko', 'Le_Rots']
# ['AlphusMtilene', '5am']
# ['Mo_Tseki', 'Ulo']
# ['sangxa', 'MmetjaRMF']
# ['vcmaxprice', 'AmirBagheri']
# ['WitsSRC', 'WineCognoscente']
# ['tshego_magic', 'LeRadioMK']
# ['theafricanchild', 'EOH_2015']
# ['Medhurst_Hall', 'theafricanchild']
# ['TheWitsJunction', 'theafricanchild']
# ['theafricanchild', 'WitsSln']
# ['EOH_2015', 'TheVoiceArtist']
# ['Medhurst_Hall', 'TheVoiceArtist']
# ['TheWitsJunction', 'TheVoiceArtist']
# ['WitsSln', 'TheVoiceArtist']
# ['BuhleNkonki', 'SouthAfrica']
# ['WitsSRC', 'dankiejeff']
# ['News24', 'peteraok']
# ['Lona_Mapoma', 'the_girlTEE']
# ['keatzkorevaar', 'UCTStudentpic']
# ['mzisibhengu', 'rhodesmustfall']
# ['Siwa_Mbara', 'vcmaxprice']
# ['MakhandeniLtd', 'PresidencyZA']
# ['tlethea', 'KasiGeeq']
# ['5FM', 'HouseOfPoppy']
# ['MokubungTTS', 'Pillz_MaZuma']
# ['ciara', 'twieterazzi']
# ['FLOTUS', 'twieterazzi']
# ['AndraDayMusic', 'twieterazzi']
# ['Siwa_Mbara', 'AttiSopitshi']
# ['usedgov', 'twieterazzi']
# ['BenjaminFogel', 'GSOCUAW']
# ['DrBiden', 'twieterazzi']
# ['_PhilaSithole_', 'mowbraySAPS']
# ['_PhilaSithole_', 'uctsrc']
# ['ThembiMrototo', 'siphojanuary']
# ['aliciakeys', 'twieterazzi']
# ['blk_jks', 'cokeyfalkow']
# ['SedzPM', 'MarvelHlungwani']
# ['R3azzy', 'MarvelHlungwani']
# ['eNCA', 'Don_Chello']
# ['Don_Chello', 'News24']
# ['NMMUSRC', 'MarvelHlungwani']
# ['TheGreatMalik_', 'UJAPK_SRC']
# ['loyisogola', 'MarvelHlungwani']
# ['Bafana_Kevin', 'uct_src']
# ['Yoboi_Eetu', 'Rochelle_Shady']
# ['Nonku101', 'SK_NdlovuPhD']
# ['PresidencyZA', 'Poetic_Hills']
# ['WitsSRC', 'Felicity_M2']
# ['Khutso_Peace', 'Felicity_M2']
# ['Jose_medupz', 'this']
# ['Director_Sphe', 'Tee_Diso']
# ['Vodacom', 'AzaniaKuali']
# ['Rochelle_Shady', '_Sybill']
# ['kreggie10', 'mmabatho_t']
# ['DamianHeinz', 'PresidencyZA']
# ['Universityof', 'SikhosanaZama']
# ['LinnMieux', 'SISONKE_JOURNO']
# ['BenamileZwane', 'notnande']
# ['Trevornoah', 'yamalisa']
# ['RelebogileM', 'SaraBCohen']
# ['RelebogileM', 'Radio702']
# ['RelebogileM', 'CapeTalk']
# ['chucksJumpoff', 'yfm']
# ['Sine_Mandyoli', 'PAYCOWC']
# ['nkalane16', 'DrGabuza']
# ['ukhozi_fm', 'DrGabuza']
# ['Tebogomaduwaa', 'twieterazzi']
# ['sibacooo', 'Julius_S_Malema']
# ['ewnupdates', 'africartoonspic']
# ['YaredtheGuy', 'MkJustSaid']
# ['sakinakamwendo', 'SifisoMdladla']
# ['billysigudla', '02reunion']
# ['Shmangz', 'loyisogola']
# ['MyANC_', 'taxi46664']
# ['AdHabb', 'taxi46664']
# ['NeleSanza', 'd']
# ['unathimsengana', 'mlu85']
# ['owenhannie', 'mlu85']
# ['eNCA', 'MissLesegoS']
# ['expressofshow', 'MphirimMphiri']
# ['amliveonsafm', 'EliasChinemore']
# ['BONGIE_MSWELI', 'SAPresident']
# ['_thabosmarts', 'MyANC_']
# ['MphoMM_', 'CapricornFM']
# ['them', 'luzibomimi']
# ['ReloSoulful', 'Danny_boym']
# ['eNCA', 'Kgothalo_T']
# ['MG_Reporter', 'Kgothalo_T']
# ['TheatreAfrica', '']
# ['RISEfm943', 'makhosikhoza01']
# ['sakinakamwendo', 'Retume']
# ['the', 'DimmyK007']
# ['NomMkhize1', 'Anele_Nzimande']
# ['leloe_m', '702JohnRobbie']
# ['BladeNzimandeMP', 'Ndu_madubela']
# ['WitsSRC', 'Moseri08']
# ['702JohnRobbie', 'twieterazzi']
# ['Mtamerri', 'MyANC_']
# ['NantesK', 'MyANC_']
# ['comp_breakfast', 'MrsKarenCooney']
# ['News24', 'prince__em']
# ['Radio702', '702JohnRobbie']
# ['Lesufi', 'MajavuThabiso']
# ['ShellsPemBroke', 'JessicaMBreakey']
# ['eNCA', 'BILLIONTOURSZA']
# ['BILLIONTOURSZA', 'ANN7tv']
# ['MelusiTweets', 'PresidencyZA']
# ['TMOKADI', 'ANN7tv']
# ['TMOKADI', 'UCT']
# ['priscanall', 'jellykid34']
# ['BladeNzimandeMP', 'MelusiTweets']
# ['Nick_Hamman', 'TshepoSeloane']
# ['BladeNzimandeMP', 'nkosiab']
# ['henkpix', 'TheCapeArgus']
# ['AnnikaLarsen1', 'eNCA']
# ['amliveonsafm', 'MakenziKenzo']
# ['kholsP', 'wits']
# ['uct', 'kholsP']
# ['neofrmthematrix', '702JohnRobbie']
# ['mojoIOL', 'TheCapeArgus']
# ['MelvinMsezane', '702JohnRobbie']
# ['mmusopitso', '702JohnRobbie']
# ['sangxa', 'Lungisa_Mzizana']
# ['EvansMathibe', 'yfm']
# ['eNCA', 'fofgirl']
# ['Hudson_Gretel', 'eNCA']
# ['EvansMathibe', 'eff29']
# ['eNCA', 'MyVoice_1']
# ['eNCA', 'Kea_AM']
# ['ukhozi_fm', 'Andisw_Khumalo']
# ['eNCA', 'Nigel_Branken']
# ['_INAGNOB_', 'Daneve_blooms']
# ['eNCA', 'CapricornFM']
# ['LeninChisaira', '263Chat']
# ['MosesMachipisa', 'LeninChisaira']
# ['iolpic', 'TheCapeArgus']
# ['WitsSRC', 'Kagiso_Pou']
# ['eNCA', 'Thipa_na']
# ['Ulo_Mkat', 'CapricornFM']
# ['Bhekamambo7', '']
# ['AdHabb', 'SigRandburg']
# ['JJ_UFS', 'SigRandburg']
# ['hajraomarjee', 'BigDaddyLiberty']
# ['KokoNdhlovu', 'Ulo_Mkat']
# ['eNCA', 'Thipapedi']
# ['PhumlaniUMajozi', 'BAFO_DLOMO']
# ['eNCA', 'MduduziTNtuli']
# ['BladeNzimandeMP', 'WimpieGrey']
# ['nealcol', 'Ttntshayi']
# ['Gomotsegang_R', 'SAPresident']
# ['Gomotsegang_R', 'PresidencyZA']
# ['MyPule_', 'isirbongz']
# ['eNCA', 'Mshula']
# ['Vuyo16', 'SihleDLK']
# ['HonourableHloni', 'HajraOmarj']
# ['MfvnOryt', 'Jambase63']
# ['Sentletse', 'Essential_KJ']
# ['UCT', 'zandimzala']
# ['CINTA_JDA', 'HammanTime']
# ['EsethuHasane', 'oliver_meth']
# ['tankiso_rakosa', 'MyANC_']
# ['tankiso_rakosa', 'PresidencyZA']
# ['tankiso_rakosa', 'WitsSRC']
# ['ramalamulaSA', 'MyANC']
# ['eNCA', 'pido_07']
# ['uct', 'MaseMahopo']
# ['kgatlan', 'MphoMM_']
# ['Leighratoh', 'MyANC_']
# ['MbalulaFikile', 'NontoNkosi']
# ['eNCA', '_TakaBusi']
# ['_Khanyisile__', 'UCT']
# ['MrSoulful_X', 'MyANC_']
# ['gerrie3', 'goitsekonopi']
# ['eNCA', 'eNCApic']
# ['THEETHATOR', 'loyisogola']
# ['THEETHATOR', 'nick_kaoma']
# ['Selebod', 'eNCA']
# ['ClicksRally', 'TuksStudent']
# ['GwedeUncle', 'maths00001']
# ['sonneillon', 'UCT']
# ['WitsSRC', 'bantu_dj']
# ['YouTube', 'Afro_Riot']
# ['eNCA', 'Mokgabo_Wame']
# ['SABCNewsOnlinepic', 'Mokgabo_Wame']
# ['WitsUniversity', 'chemoshesh']
# ['nealcol', 'kdee_Naks']
# ['kdee_Naks', 'sapresident']
# ['wikusdutoit', 'MyANC_']
# ['MeliLumko', 'MyANC_']
# ['ANCYL_GP', 'MeliLumko']
# ['UCT', 'ian_brink']
# ['kamo_Tee', 'Twabiso']
# ['Leighratoh', 'DynamicDango']
# ['SfisoRabukana', 'MyNews24']
# ['KamvelihleGoba', 'CassperNyovest']
# ['KamvelihleGoba', 'akaworldwide']
# ['YouTube', 'SihleSocishe']
# ['THEETHATOR', 'sapresisdent']
# ['AryeKellman', 'LoyisoGola']
# ['AryeKellman', 'JasonDerulo']
# ['UJAPK_SRC', 'terrytrap']
# ['702JohnRobbie', 'gareth6pike']
# ['9ec7857d48dc408', 'PowerDrive987FMpic']
# ['SkinnyAssLelow', 'therealmotso_']
# ['SASCO_Jikelelepic', 'oliver_meth']
# ['uctnews', 'mothowalebowa']
# ['tyrenene', 'UPTuks']
# ['RuskyMC', 'Cais_Cassius']
# ['Sonia_Phalatse', 'BladeNzimandeMP']
# ['mlungisi_prince', 'Macpercy']
# ['THEETHATOR', 'CassperNyovest']
# ['Ngaa_turn_dwey', 'AfricaUniversity']
# ['Sekese_Z', 'Rustyseswike']
# ['Julius_s_malema', 'Senzo__S']
# ['floydshivambu', 'Senzo__S']
# ['Senzo__S', 'UPTuks']
# ['Senzo__S', 'witsstudent']
# ['Julius_S_Malema', 'Glen_Zito']
# ['therealmotso_', 'Cais_Cassius']
# ['WitsSRC', 'scott_hunt']
# ['MyANC_', 'realxolie']
# ['AdHabb', 'oliver_meth']
# ['oliver_meth', 'WitsUniversitypic']
# ['MrMasina', '50cent']
# ['Julius_S_Malema', 'sr501e']
# ['medschool', 'Tumistar']
# ['JoanneGJosephpic', 'lenyarosello']
# ['marieclaire_sa', 'assocmedia']
# ['TrendieZA', 'IntertwEAT']
# ['mlungisi_prince', 'SbohSibisi']
# ['eNCA', 'CathyMohlahlana']
# ['eNCA', 'JoanneGJosephpic']
# ['KasiGeeq', 'MyANC_']
# ['lenyarosello', 'encapic']
# ['XolaniMade', 'TazEssop14']
# ['eNCA', '1REELO']
# ['ZubzS_', 'LB_Langa']
# ['TomiRikods', 'mlungisi_prince']
# ['Mzo_XO', 'theeALPHAMAN']
# ['NizzyOG', 'mlungisi_prince']
# ['mlungisi_prince', 'Duwinsky']
# ['Ludwe01', '_JayyBun']
# ['_JayyBun', 'KayDavillain']
# ['MbuyiPajero', 'GwedeUncle']
# ['Pununum', 'Ludwe01']
# ['Pununum', 'KayDavillain']
# ['mlungisi_prince', 'OyenaD']
# ['8am', 'lenyarosello']
# ['8am', 'eNCA']
# ['JerriMokgofe', 'ntsikimazwai']
# ['wishcoat', 'Von_WR']
# ['eNCA', 'Feather_Ruffler']
# ['PhlyZoey', 'uZamo_']
# ['THEETHATOR', 'akaworldwide']
# ['akaworldwide', 'NJ_Khathi']
# ['Julius_S_Malema', 'NgoatoNkoane']
# ['NorthWestZA', 'encanews']
# ['Nape_MM', 'uCt']
# ['rhizomia', 'camila_vallejo']
# ['rhizomia', 'DanielleBowlerpic']
# ['i_Nxakanxaka', 'Twitter']
# ['THEETHATOR', 'mmusimaimane']
# ['MbalulaFikile', 'Rothabisa']
# ['dasoufh', 'UFHSRC']
# ['eNCA', 'dasoufh']
# ['Laurizee', 'Milliey__']
# ['strOberrybOmpi', 'akaworldwide']
# ['Medhurst_Hall', 'eoh_res']
# ['MaksMolomo', 'sfundz']
# ['WilliamModise5', 'J']
# ['Blade', 'WilliamModise5']
# ['UKZN', 'Africa665']
# ['FundiNtuli', 'akaworldwide']
# ['akaworldwide', 'Bluelight_Em']
# ['_Lxtho', 'LB_Langa']
# ['Ape_Vazpic', 'Inge_Wulff']
# ['BladeNzimandeMP', 'Mikey_Spike']
# ['Michel_Risto', 'ThisisTheo_King']
# ['Michel_Risto', 'Lefa_M_']
# ['SAFCEI', 'Act4EcoJustice']
# ['FundiNtuli', 'MyANC_']
# ['Snrdo', 'Be_A_stevie']
# ['eNCA', 'BuhleSomeketa']
# ['WitsSRC', 'BuhleSomeketa']
# ['NorthWestZA', 'news24']
# ['SiyaBunny', 'BladeNzimandeMP']
# ['Nockproxy111', 'RuskyMC']
# ['MyANC_', 'NtokieNtokist']
# ['POWER987News', '']
# ['MyANC_', 'steph_gareth']
# ['will_dhliwayo', 'NYU']
# ['Lefa_M_', 'Be_A_stevie']
# ['Davos', 'MSovara']
# ['ScaLuvo', 'MyANC_']
# ['_ANTIMajola', 'MarcXabiso']
# ['MaksMolomo', 'mpuwoa']
# ['DMShowZA', 'Pontsho_Pilane']
# ['DMShowZA', 'WitsUniversity']
# ['Yvette_Aloe', 'Katlego_Tefu']
# ['WitsSRC', 'Thebe01342335']
# ['will_dhliwayo', '3rdDegree_etv']
# ['Zero_Dyantyi', 'akaworldwide']
# ['Xitha_M', 'MooseMuesli']
# ['Be_A_stevie', 'MaTSHEEdiso_M']
# ['thamsanqabengu', 'zungusthabiso']
# ['thamsanqabengu', 'Regrann']
# ['PSASECWC247', 'mojoIOL']
# ['KEVIIN_LXXXVIII', 'Milliey_Lovings']
# ['zanews', 'mynameisjermpic']
# ['Empress_Skye', 'Otumi_']
# ['SAPresident', 'temba_dee']
# ['chichiglobal', 'Anele_Madlala']
# ['Kgotsi_Chikane', 'MG_Reporterpic']
# ['pintsizemedia', 'Niche_Radio']
# ['Oliver_Speaking', 'TshepoGoba']
# ['Oliver_Speaking', 'akaworldwide']
# ['leeroyleeta', 'Be_A_stevie']
# ['JLephalala', 'sharethis']
# ['MyANC_', 'Bruz786']
# ['MyANC_', 'mduketsi_com']
# ['twitta_fiend', 'MyANC_']
# ['Milliey_Lovings', 'TinoMatz']
# ['O_Rakgotho', 'MyANC_']
# ['GeorgeLezerpic', 'Netwerk24']
# ['Demsonmafase', 'VukosiNgoveni']
# ['ThomHolderpic', 'ewnreporter']
# ['KONTROL_MAK', 'BokangWrote']
# ['karabzy', 'Brits']
# ['eNCA', 'MyLifeAsSne']
# ['eNCA', 'NoxieSibiya']
# ['AAN7', 'NoxieSibiya']
# ['sharronmacb', 'akaworldwide']
# ['Sebastianmeso', 'madrizz33']
# ['ABSA', 'luzibomimi']
# ['akaworldwide', 'astoldbytwiist']
# ['KEVIIN_LXXXVIII', 'akaworldwide']
# ['akaworldwide', 'Seth_Zwide']
# ['DaNewtAndStuff', 'BuhleNkonki']
# ['KEENANMULVANEY', 'ROSEKOTZE']
# ['VERNON_GT', 'akaworldwide']
# ['Reflexion007', 'akaworldwide']
# ['UPTuks', 'wamodimosana']
# ['akaworldwide', 'mbongenikupiso']
# ['angeloclouw', 'SarahGodsell']
# ['Rragwe_Bana', 'akaworldwide']
# ['MinnieDlamini', 'KEVIIN_LXXXVIII']
# ['Julius_S_Malema', 'lessonsCoZa']
# ['Julias_Malema', 'lessonsCoZa']
# ['Chabz_Classic', 'akaworldwide']
# ['LindaMakhoba', 'akaworldwide']
# ['LindyMtshali', 'NomMkhize1']
# ['Wentzello', 'WoolworthsFood']
# ['ThatGuy4D', 'Mawande_RSA']
# ['YouTube', 'KarensComments']
# ['SafmRadio', 'EliasChinemore']
# ['dasoufh', 'DailyDispatch_DD']
# ['Power987', 'dasoufh']
# ['TruFMonline', 'dasoufh']
# ['ThatGuy4D', 'Easy_Kay_']
# ['SiphoseSizwe', 'akaworldwide']
# ['MbebeAzola1', 'akaworldwide']
# ['bian5a_vb', 'SAPresident']
# ['CHANCEMANIA', 'Akaworldwide']
# ['TsepisoNzayo', 'me']
# ['OhItsDaddy', 'ronniie__xo']
# ['OhItsDaddy', 'Yoboi_Eetu']
# ['WitsSRC', 'VuyoKuboni']
# ['King_Zweli', 'akaworldwide']
# ['ewnupdatespic', 'wizi_T']
# ['UberFacts', 'ThembeniLucia']
# ['CassperNyovest', 'NdadaJ']
# ['akaworldwide', 'NdadaJ']
# ['ewnreporter', 'JustKoyanapic']
# ['EconFreedomZA', 'mash_kid']
# ['Raphaell_D', 'vuyo95_']
# ['Raphaell_D', 'LeVodkaSA']
# ['eNCA', 'MissExotik']
# ['MyANC_', 'MissExotik']
# ['Netwerk24', 'SamanthavdBerg1pic']
# ['Aphro3tic', 'akaworldwide']
# ['JHB', 'Nnyaameka']
# ['Raphaell_D', 'Geoff_Tweeting']
# ['Raphaell_D', 'CyberGuarana']
# ['simphiwedana', 'loyisogola']
# ['LouieVanWolf', 'fkaprincessehm']
# ['LouieVanWolf', 'ronniie__xo']
# ['LouieVanWolf', 'Yoboi_Eetu']
# ['KGH_Maota', 'trapsonly']
# ['Maboniz', 'akaworldwide']
# ['Wits', 'Mashobane61']
# ['Raphaell_D', 'Easy_Kay_']
# ['mamzmolepo', 'Harold_Ferwood']
# ['Vodacom111', 'TEBANG']
# ['mtn', 'TEBANG']
# ['cellc', 'TEBANG']
# ['bridgebosstlee', 'Fokisa_']
# ['RoDnEy_MaC_yAr', 'Milliey_Lovings']
# ['SayedDhansay', 'ewnupdatespic']
# ['JacaNews', 'Slindelo_Mpic']
# ['eNCA', 'HOHOH']
# ['Sukude_', 'MyANC_']
# ['KhanyaGqiyazana', 'magoba_ZAR']
# ['Bra_Sten', 'Akaworldwiide']
# ['Bra_Sten', 'CassperNyovest']
# ['PhosafunctionSA', 'kayrams']
# ['PhosafunctionSA', 'SydThaninja']
# ['DavidFundraiser', 'MyANC_']
# ['eNCA', 'SizzleOndaBass']
# ['News24', 'SizzleOndaBass']
# ['imraanchristian', 'MikaelaNhondo']
# ['CassperNyovest', 'oStefanoDimera']
# ['akaworldwide', 'oStefanoDimera']
# ['MrCashtime', 'oStefanoDimera']
# ['Dean_d13', 'IOLpic']
# ['JuniaRayjan', 'CassperNyovest']
# ['JuniaRayjan', 'SizweDhlomo']
# ['Lailo_Rammy', 'daya_sade93']
# ['PhilaniGoma', 'Matsobane_mp']
# ['Latoya_Mwix', 'akaworldwide']
# ['Netwerk24', 'claudimailovichpic']
# ['MiljoenvirSteve', 'tanbotha24']
# ['tanbotha24', 'Pienktamatie']
# ['Yeye_Meanaj', 'loyisogola']
# ['akaworldwide', 'Abu_Mangali']
# ['loyisogola', 'Tshepiso_29']
# ['Tshepiso_29', 'akaworldwide']
# ['MyANC_', 'PlanetZuma']
# ['Aimee2803', 'MarkPalmerComic']
# ['Aimee2803', 'MyCityByNight']
# ['akaworldwide', 'bibo_187']
# ['mphokoqopapi', 'akaworldwide']
# ['BoyceMathebula', 'sir_toy']
# ['llekoc', 'twittellect']
# ['mafa_bavuma', 'Mara_mbangc']
# ['joaomatthews_', 'CliffCentralCom']
# ['urbanjodi', 'politicsweb']
# ['bonang_m', 'snash_145']
# ['TUT', 'GinindaAS']
# ['inkanyezi_Sugs', 'thabang_mapena']
# ['hawkseye6', 'EFF_UJ_DFC']
# ['AdHabb', 'DalenLance']
# ['VERNON_GT', '_Andy_Fierce']
# ['Kovsies', 'Babinyana']
# ['iLuvuyo', 'PresidencyZA']
# ['erasmusmarieee', 'lorendzero9']
# ['eNCA', 'sanosanele']
# ['MyANC_', 'sanosanele']
# ['Sotterjr', 'akaworldwide']
# ['Sotterjr', 'CassperNyovest']
# ['varsity', 'xindelendele']
# ['LondaNtuli', 'akaworldwide']
# ['Bheki_Nyathi', 'PatriciaDeLille']
# ['VuyoMadikane', 'uThabisa_']
# ['anccadres', 'sanosanele']
# ['SlyPod', 'BladeNzimandeMP']
# ['eNCAnewspic', 'Sibuuu_m']
# ['RenaldoSchwarppic', 'Netwerk24']
# ['akaworldwide', 'ThatoDM']
# ['safmmiddaylive', 'mzisibhengu']
# ['eNCA', 'Bongiwe_Khumalo']
# ['OricleSA', 'Wits']
# ['SammieNeshuku', 'SAMKELO18']
# ['GautengNigel', 'MyANC_']
# ['eNCA', 'MokoenaSays']
# ['Pablo_Escobih', 'Akio_DJ_ID']
# ['JustNtando', 'akaworldwide']
# ['MzansiMaasai', 'CliffCentralCom']
# ['akaworldwide', 'MizzDazzleMusic']
# ['GpPaks', 'Barry_Roux']
# ['Real_LeFranc', 'fkaprincessehm']
# ['Real_LeFranc', 'Yoboi_Eetu']
# ['mahleyz', 'akaworldwide']
# ['MondliMungwe', 'Dbnchillies']
# ['BladeNzimandeMP', 'TumWierdKid']
# ['Natz0711', 'Iam_Thorns']
# ['AyandaDlamini_', 'MyANC_']
# ['loyisogola', 'thusoworldwide']
# ['mlungisi_prince', 'IamMow_saH']
# ['BladeNzimandeMP', 'Naleli_']
# ['AngieMotshekga', 'Naleli_']
# ['jacobzuma', 'Naleli_']
# ['AdHabb', 'Naleli_']
# ['akaworldwide', 'KasiMagesha13']
# ['Netwerk24', 'alet87pic']
# ['PrivilegeChecker', 'TheDavidAlves']
# ['King__Mbuso', 'Dumi_Jere']
# ['n2wice', 'akaworldwide']
# ['swa_mlawuza', 'Simzqb']
# ['JustHlaz_', '_TheBlackGuy']
# ['MzansiMaasai', 'pontsho_pilane']
# ['eNCA', 'JSekgoro']
# ['JSekgoro', 'Bongiwe_Khumalo']
# ['mynameisjerm', 'Savo_Heleta']
# ['RamonaNaidoo', 'BulletToothVal']
# ['andilemasondo1', 'andilemasond1']
# ['LuskyDJ', 'ParksTauCOJ']
# ['craboh', 'Veli_Mbuli']
# ['YouTube', 'Ngwenya_Nkomo']
# ['PHAMUWA', 'SAPresident']
# ['salmau5_2', 'akaworldwide']
# ['Dukeof254', 'nduyamuthama']
# ['DidiLeepile', 'eNCA']
# ['SuneDT', 'GerdaDS']
# ['JacaNews', 'GerdaDS']
# ['JayTip_SA', '_Jay69']
# ['JayHektic', 'akaworldwide']
# ['Thobile630', 'kadykats']
# ['Dukeof254', 'LarryMadowo']
# ['junior_mutula', 'Dukeof254']
# ['curateByo', 'realnigelndlovu']
# ['CurateZAR', 'realnigelndlovu']
# ['CulxureMagZim', 'realnigelndlovu']
# ['GilmoreTee', 'realnigelndlovu']
# ['realnigelndlovu', 'AfricaMedia54']
# ['Pontsho_Pilane', 'feministstokvel']
# ['Pontsho_Pilane', 'GoodBeautyDiary']
# ['iloveginger4', 'CPUT']
# ['Pontsho_Pilane', 'SAPregAndParent']
# ['GoodHairDiaries', 'Pontsho_Pilane']
# ['ParliamentOfRSA', 'dasoufh']
# ['Masipa_', 'Raediology']
# ['EsethuHasanepic', 'BeynonSammy']
# ['Lungile_Se', 'BladeNzimandeMP']
# ['Netwerk24', 'JH_Krugerpic']
# ['iloveginger4', 'simphiwedanapic']
# ['Nani_Dubula', 'TheTigerCSD']
# ['NandosSA', 'Nani_Dubula']
# ['Nani_Dubula', 'Nestle']
# ['Nani_Dubula', 'WOOLWORTHS_SA']
# ['realnigelndlovu', '263Chat']
# ['Phislash', 'MbalulaFikile']
# ['etvpic', 'AFRICAN_JOURNO']
# ['B_TheDreamer', 'Trevornoah']
# ['eNCA', 'KopsM']
# ['KopsM', 'Bongiwe_Khumalo']
# ['mimsta_ec', 'Ah_nayP']
# ['Leptonic2015', 'IAmCoeteze']
# ['medical', 'Botshelo_89']
# ['safmpmlive', 'msith']
# ['masemolalucias1', 'mokwena_doctorpic']
# ['UKZN', 'chatlas']
# ['chatlas', 'Univenofficial']
# ['nathimankayi', 'PhiwahJnr']
# ['sunnysidehobo1', 'MyANC_']
# ['mzaykesman', 'WitsSRC']
# ['eNCA', 'C31Wilki']
# ['Babby_king', 'NomiShongwe']
# ['eNCA', 'portiaqhinaposh']
# ['portiaqhinaposh', 'Bongiwe_Khumalo']
# ['CapeTalk', 'pjchudson']
# ['Maestro_Ed', 'thabang_EM']
# ['CassperNyovest', '1dile_M']
# ['safmpmlive', 'Makgaledise']
# ['occupySOAS2015', 'SOASoccupation']
# ['occupySOAS2015', 'WitsUniversityhttp']
# ['rragwe_Spunanki', '2Tainted4Wrdz']
# ['MbalulaFikile', 'PamHlehle']
# ['WitsSRC', 'occupySOAS2015']
# ['Ndumie_Sifo', 'I_A_MRoyalty']
# ['PresidencyZA', 'monjackson']
# ['eNCA', 'Nontobek0Sibisi']
# ['MsMeJanine', 'FreeEnergybot']
# ['lean_mawish', 'CliffCentral']
# ['Luyanda_Mbi', 'Miss_Gallie']
# ['Thee_MsLee', 'Charliebang']
# ['mzeemushaandja', 'Pontsho_Pilane']
# ['deroxrimez', 'PresidencyZA']
# ['_INAGNOB_', 'Be_A_stevie']
# ['lean_mawish', 'FikileMbalula']
# ['Lu_Estelle', 'Palesa_Tshabz']
# ['qz', 'papa_action']
# ['Vuyo16', 'LeboGunguluza']
# ['Julius_S_Malema', 'ThaboFresh']
# ['me', 'iamDasKapital']
# ['akaworldwide', 'anelisa_kakaza']
# ['Li_Dwight', 'PresidencyZA']
# ['YouTube', '4E7HER']
# ['MyANC_', 'earlseptember']
# ['TebogoMonama', 'ReporterStarpic']
# ['FoulkesBrau', 'News24']
# ['LuskyDJ', 'PresidencyZA']
# ['this', 'jnr_lucifer']
# ['MyANC_', 'jnr_lucifer']
# ['keBENJI', 'Charliebang']
# ['hlons1', 'eNCA']
# ['hlons1', 'Bongiwe_Khumalo']
# ['PhiwahJnr', 'IngeBeukes13']
# ['Julius_S_Malema', '_butiMo']
# ['TebogoMonama', 'Ulo_Mkat']
# ['WitsMedSchool', 'Akos_Nana']
# ['Ulo_Mkat', 'Akos_Nana']
# ['Bikomfident', 'Katley_FBO']
# ['Mgilija5', 'CassperNyovest']
# ['Mgilija5', 'RealBlackCoffee']
# ['UCT', 'Wendy_Mothata']
# ['Moses_Nku', 'keBENJI']
# ['akaworldwide', 'CallMe_LTee']
# ['Ulo_Mkat', 'NomfundoEngler']
# ['ComfortKnight', 'CassperNyovest']
# ['DeeRolaz', 'CulpritEnterpic']
# ['JaninevWyk', 'Government']
# ['JaninevWyk', 'Ministers']
# ['JaninevWyk', 'UniversityManagement']
# ['JaninevWyk', 'SAPS']
# ['Media', 'JaninevWyk']
# ['CallMeAfriKa', 'remythequill']
# ['CallMeAfriKa', 'LiveVIPZA']
# ['mmusimaimane', 'jnr_lucifer']
# ['Bones_Marapo', '_Dibolo']
# ['yo_lisa92', 'CPUT']
# ['TheCapeArguspic', 'yo_lisa92']
# ['eNCAnewspic', 'RSApolitics']
# ['lenyarosello', 'akaworldwide']
# ['Abbey_McMOF', 'uVuri_']
# ['ZCawe1', 'PortiaMoemedi']
# ['gary_kai', 'JustinTrudeau']
# ['DMShowZA', 'MzansiMaasai']
# ['eNCA', 'Tes_Beau']
# ['SABCNewsOnlinepic', 'Tes_Beau']
# ['eNCA', 'UFHSRC2015']
# ['GodfreyTafipic', 'WhoIsPetlo']
# ['Bobolonkoks', 'DtSanchez_JTB']
# ['Lu_Estelle', 'Private']
# ['Ulo_Mkat', 'artindira']
# ['Macpercy', 'bones_marapo']
# ['newmediajude', 'CPUT']
# ['SAPS', 'KayzeePheHey']
# ['Lu_Estelle', 'Witz']
# ['eNCA', 'ashenkea']
# ['__lungile', 'BhucwaM']
# ['EconFreedomZA', 'NdumisoNgalo']
# ['fofgirl', 'MTNza']
# ['Philani_mini_pH', 'tuks']
# ['CulpritEnterpic', 'Moses_Nku']
# ['Chili_m2', 'BrianDaveZa']
# ['BrianDaveZa', 'CulpritEnterpic']
# ['Mgilija5', 'cputstudents']
# ['StandardBankZA', 'Pvleng']
# ['Pvleng', 'Absa']
# ['NandosSA', 'Pvleng']
# ['Natasha_Ryder5', 'Social_Angel']
# ['LiveVIPZA', 'AbigailJavier_']
# ['Sir_Nduna', 'nick_kaoma']
# ['Candice_Chirwa', 'akaworldwide']
# ['Khayelitsha', 'torochaser']
# ['SbohSibisi', 'NjabuloLukie']
# ['eNCA', 'BrendanvonEssen']
# ['BrianDaveZa', 'toysosha']
# ['hloni_lk', 'NMMU4U']
# ['thvba', 'sk_ndlovuPhD']
# ['MajestyKagiso', 'thabang_EM']
# ['LoogheeTheBlvr', 'iam_KbL']
# ['thvba', 'akaworldwide']
# ['thvba', 'Wits']
# ['simphiwedana', 'eNCA']
# ['eNCA', 'akaworldwide']
# ['Vodacom', 'babagrr']
# ['babagrr', 'MTNza']
# ['CellC', 'babagrr']
# ['Telkom', 'babagrr']
# ['WitsFeesMustFall', 'babagrr']
# ['sk_ndlovuPhD', 'isirbongz']
# ['NandieM', 'MyANC_']
# ['eNCA', 'Africa_Rise']
# ['Happiness_FG', 'akaworldwide']
# ['KayzeePheHey', 'PresidencyZA']
# ['SbohSibisi', 'akaworldwide']
# ['siyablvx', 'CassperNyovest']
# ['SbuTshigabe', 'NjabuloLukie']
# ['eNCA', 'uMavesta']
# ['IncenseSA', 'MsBikitsha']
# ['Bones_Marapo', 'JustThapy']
# ['serendipretti', 'pearli_kinzZ']
# ['eNCA', 'ActiveKTM']
# ['iamprinceoscar', 'UdyUmo']
# ['finalmixent', 'UdyUmo']
# ['MyANC_', 'Nappy_ChinHead']
# ['EconFreedomZA', 'Nappy_ChinHead']
# ['Tlouu_Kganyago', 'TS_Sithole']
# ['Z_Hlumelo', 'akaworldwide']
# ['Nessah_V', 'matthew91c']
# ['kingTablets', 'akaworldwide']
# ['Wits', 'kingTablets']
# ['bayanda', 'Bhintsintsi']
# ['bayanda', 'Sthezozo']
# ['all', 'sipi_naz']
# ['themasonsixgod', 'akaworldwide']
# ['nate_swart', 'MyANC_']
# ['nate_swart', 'jacobzuma']
# ['nate_swart', 'eNCA']
# ['SbohSibisi', 'leetha__']
# ['mosscoDOLLAR', 'Akio_DJ_ID']
# ['LAWRENCABLE', 'akaworldwide']
# ['Sir_Ntusi', 'OfficialMpumi']
# ['T_Lehutso', 'leetha__']
# ['Sandawana_', 'eNCA']
# ['akaworldwide', 'chepapeKL']
# ['IsibayaOverHoes', 'sk_ndlovuPhD']
# ['byron________', 'WitsSRC']
# ['byron________', 'WitsUniversity']
# ['brizzy1080', 'akaworldwide']
# ['Yxndy', 'leetha__']
# ['terembecherono', 'akaworldwide']
# ['Mahlabanemp', 'akaworldwide']
# ['TUMI02GP', 'Thiso_Thaso']
# ['Thapy2', 'Naso_Jaye']
# ['Bones_Marapo', 'Naso_Jaye']
# ['sk_ndlovuPhD', 'NteoPrudence']
# ['WitsSrc', 'BlacksoulSiziba']
# ['WitsUniversity', 'Whitthread']
# ['NcubeNoluthando', 'akaworldwide']
# ['Pontsho_Pilane', 'DeeNkomo_']
# ['bona_baratile', 'akaworldwide']
# ['DASOWits', 'DASO_UP']
# ['DASONMMU', 'DASO_UP']
# ['DASO_UP', 'DASOUCT']
# ['leogsmit', 'Zee_ODeal']
# ['eNCA', 'Thabiso_TwaaH']
# ['nokuthulandala', 'MyANC_']
# ['Ray_Kamolane', 'PresidencyZA']
# ['Julius_S_Malema', '_Babazile']
# ['daz_inc_', 'akaworld']
# ['TsebangM', 'Lesufi']
# ['fofgirl', 'TumishoMasha']
# ['varsitycollege', 'blaze_ledouche']
# ['akaworldwide', 'TumisangMrHillz']
# ['percyzvomuya', 'uMandlakazi']
# ['JZ_Africa', 'akaworldwide']
# ['stiga_junior', 'akaworldwide']
# ['OfficialMpumi', 'akaworldwide']
# ['eNCA', 'aCko___']
# ['Vuyo16', 'akaworldwide']
# ['Glen_Zito', 'SAPresident']
# ['the', 'VuyelwaSibene']
# ['RMadiba', 'eNCA']
# ['NMMU', 'AfrikanJeanyus']
# ['AKA', 'e6acbf6bca79403']
# ['NolwaziShange', 'NkamoNkamoheng']
# ['khule_shabangu', 'akaworldwide']
# ['Comrade_Chef', 'NGettyD']
# ['usledge', 'akaworldwide']
# ['usledge', 'Wits']
# ['Linden', 'MorenaTheSquire']
# ['Bongz275', 'lwazidladla07']
# ['Robbyrebelo', 'MmusiMaimanepic']
# ['psyzwe_1', 'akaworldwide']
# ['akaworldwide', '_VeeYouWhyEye_']
# ['TheAttaMonster', 'stopbeingfamous']
# ['TheAttaMonster', 'SankofaBrown']
# ['eNCA', 'pako_tong']
# ['sabconline', 'pako_tong']
# ['pako_tong', 'ANN7tv']
# ['LiaKoorapetse', 'DjPride1']
# ['misspops86', 'UCT']
# ['Wits', 'misspops86']
# ['eNCA', 'Tokcik']
# ['Comrade_Chef', 'Pholoho']
# ['akaworldwide', 'BkayYusef']
# ['Lefa107', 'Thato_Smal']
# ['Moses_Nku', 'akaworldwide']
# ['Moses_Nku', 'CassperNyovest']
# ['Peter_O_Herring', 'SAPresident']
# ['5thAvenueShow', 'Naso_Jaye']
# ['Comrade_Chef', 'Seth_Zwide']
# ['rhodesmustfall', 'GroundUp_News']
# ['BladeNzimandeMP', 'GroundUp_News']
# ['UFSwebpic', 'KovsieFM97']
# ['ThinashakaM', 'leratokojoana']
# ['Mngxitama', 'KomradeGeorge']
# ['KomradeGeorge', 'ANN7tv']
# ['Julius_S_Malema', 'TylerYawer']
# ['EconFreedomZA', 'TylerYawer']
# ['MbuziBrandPusha', 'akaworldwide']
# ['Comrade_Chef', 'ThusiSabelo']
# ['njayakhe', 'Z_Hlumelo']
# ['UCT_newspic', 'MawereSibanda']
# ['Gert_LeNinja', 'taybeats']
# ['thamsanqabengu', '_bonga']
# ['BlackGuy_WTY', 'BEAST_NGWENYA']
# ['EconFreedomZA', 'RamatsetseRams']
# ['News24', 'ThatoDM']
# ['MotswedingFM', 'ThatoDM']
# ['eNCAnews', 'ThatoDM']
# ['CptEntrepreneur', 'PresidencyZA']
# ['V_dot4U', 'sasco']
# ['Neo_Mahame', 'jhbwater']
# ['Chris_AwesomeZA', 'akaworldwide']
# ['Moses_Nku', 'Sentletse']
# ['mashiyanef', 'Sentletse']
# ['RhodesMustFallpic', 'Harold_Ferwood']
# ['MbalulaFikile', 'MO_kAtz7']
# ['iamjohnoliver', 'AnnaMartFourie']
# ['Julius_S_Malema', 'israel_morena']
# ['eNCA', 'artindira']
# ['itu_nadia', 'DeepMarvin']
# ['Sentletse', 'Edd_Everything']
# ['Bongz275', 'Bra_TP']
# ['SirJali_NJ', 'UnizuluOngoye']
# ['atishjogi', 'Jabulani_X']
# ['the_dti', 'CptEntrepreneur']
# ['Sentletse', 'NtshepyK']
# ['BongoMuffing', 'EmmahMabye']
# ['Luther_YM', 'stellenbosch']
# ['Stara_SeFreshe', 'taybeats']
# ['BBCAfrica', 'waresgemma']
# ['AneliMbude', 'halfjill_2010']
# ['WitsUniversity', 'babagrr']
# ['babagrr', 'UPTuks']
# ['Brother_TP', 'AfricanSnobb']
# ['Burn_nie', 'AfricanSnobb']
# ['SA_Celebs', 'akaworldwide']
# ['imramushu', 'Oagile_']
# ['akaworldwide', 'ratshivhadelo']
# ['lragaval', 'MyANC_']
# ['lragaval', 'MmusiMaimanepic']
# ['akaworldwide', 'thenewvoiceSA']
# ['Snapchat', 'ftchapita']
# ['asolwa96', 'IRAWA_NEWS']
# ['_Vuincento', 'MaxwellUrbanhit']
# ['jacobinmag', 'CandessK']
# ['JustStar_', 'TshepiJonathan']
# ['Tumzaza3', 'Julius_S_Malema']
# ['Zoe_Goduka', 'MissLopi']
# ['CapeTalk', 'CPUT']
# ['nghalani_', 'akaworldwide']
# ['Sentletse', 'Charliebang']
# ['all', 'MakgalaTweets']
# ['JacaNewspic', 'Slindelo_M']
# ['akaworldwidepic', 'Billal_Mabuza']
# ['Oslimax', 'akaworldwide']
# ['Lu_Estelle', 'sirkhens']
# ['SizweDhlomo', 'Da_Last_Leta']
# ['ThatDudeBeeKay', 'kanyewest']
# ['b_bongzeey', 'Sentletse']
# ['powerfm', 'OratileMatlhaku']
# ['Mmusimaimane', 'ndumis_mthiyane']
# ['SASCO_Jikelelepic', 'ndumis_mthiyane']
# ['vnmstr', 'TshepiJonathan']
# ['NapsterJan', 'imramushu']
# ['Sentletse', 'K0K1B3AR']
# ['ChiefExo', 'Sentletse']
# ['Liberebil', 'YouTube']
# ['Sentletse', 'Pkay_O31']
# ['Uncle_JayB', 'News24']
# ['EFF', 'iviwengudule']
# ['ANC', 'iviwengudule']
# ['brettfisha', 'BrettFishA']
# ['Mellz_future', 'omphemetsemoche']
# ['ewnupdates', 'akaworldwide']
# ['KEVIIN_LXXXVIII', 'iamkateko_SA']
# ['king_damane89', '_Hlozar']
# ['_hpoS', '_Hlozar']
# ['KushTrev', 'akaworldwide']
# ['Kokwani_Zitha', 'hospital']
# ['2lanyMvimbi', 'PresidencyZA']
# ['shazlns', 'akaworldwide']
# ['shazlns', 'masterAflat']
# ['mojoIOLpic', 'IOL']
# ['joyful_someone', 'BongoMuffing']
# ['MyANC_', 'OtherWandi']
# ['katlego_93', 'DeepMarvin']
# ['News24', 'TheMullerKid']
# ['ufuthie', 'CassperNyovest']
# ['Queen_Melanin7', 'VaughnThePoet']
# ['GroundUp_news', 'ashleighfurlong']
# ['DASO_UFS', 'IRAWA_NEWS']
# ['tjaartwalt', 'IRAWA_NEWS']
# ['BladeNzimandeMP', 'ZimPafa']
# ['ZimPafa', 'MyANC_']
# ['Vhasaman', 'mulalofrank']
# ['Julius_S_Malema', 'mulalofrank']
# ['RhodesUni', 'etto07']
# ['NandieM', 'Enca']
# ['o_biff', 'MyANC_']
# ['o_biff', 'SAPresident']
# ['Nipho_Reserved', 'ChizamaSays']
# ['asi_roc', 'MyANC_']
# ['asi_roc', 'ANCMPS']
# ['MbalulaFikile', 'asi_roc']
# ['asi_roc', 'PresidencyZA']
# ['MbalulaFikile', 'mulalofrank']
# ['Sentletse', 'iamLavida']
# ['CyberGuarana', 'NjabuloLukie']
# ['HonourableHloni', 'Powerfm987pic']
# ['eNCA', 'Mogatosi_Kabelo']
# ['Edu_Ambassadors', 'eNCA']
# ['demtiro', 'PresidencyZA']
# ['GMoshweu', 'eNCApic']
# ['HYESUMEOW', 'iSexceptional']
# ['NdiHudgens', 'Sentletse']
# ['WitsSRC', 'Cee_Wayne']
# ['ILLCapitano94', 'sivgreyson']
# ['sivgreyson', 'loboslooon']
# ['Kate_xxii', 'NWUPUK']
# ['Kate_xxii', 'VaalNWU']
# ['Kate_xxii', 'NWUMafikeng']
# ['imramushu', 'Gerald_Gee1']
# ['ablestudio', 'eBay']
# ['LeXhosaGuy', 'akaworldwide']
# ['LeXhosaGuy', 'MzLee_']
# ['chatlas', 'BraLuvo']
# ['Clayton_Moyo', 'jessiedendere']
# ['Eduloansa', 'mokamikhutso']
# ['NicoleBombard', 'MyANC_']
# ['sengwayo8', 'minister']
# ['Gopolang_Lebone', 'akaworldwide']
# ['PhiweMandondo', 'iamLavida']
# ['JustSeth_', 'Katz10_Lenyora']
# ['Comrade_Chef', 'Katz10_Lenyora']
# ['NteoPrudence', 'akaworldwide']
# ['bonie077', 'Ulo_Mkat']
# ['EarlKay_SA', 'XiluvhaKomane']
# ['MrPoole14', 'Ulo_Mkat']
# ['VuyiKubeka', 'IRAWAPost']
# ['WitsSRC', 'mandlamZA']
# ['ASSEsolidarite', 'Louisaudetg']
# ['Steph_Karen', 'skycapta']
# ['Lu_Estelle', 'school']
# ['Thato_Legend', 'CellCpic']
# ['ToussaintTKN', 'Miss_Gallie']
# ['shamiela_fisher', 'CapeTalk']
# ['langasifisor', 'rallies']
# ['eNCA', 'mandlamZA']
# ['EconFreedomZA', 'mandlamZA']
# ['madblackqueer', 'sinazo_mbanyaru']
# ['MpiloNdlovu_', 'MbalulaFikile']
# ['SmirnoffSA', 'zee_xanga']
# ['SABreweries', 'zee_xanga']
# ['Chomey_V', 'ThobaTheDrummer']
# ['WitsSRC', 'MashSammy']
# ['akaworldwide', 'tarantular']
# ['mzezbae', 'LiveVIPZA']
# ['akaworldwide', 'lynnvspeppa']
# ['mandlamZA', 'akaworldwide']
# ['lindarni', 'Nerdz_R_Us']
# ['MbalulaFikile', 'Nerdz_R_Us']
# ['Ndamononghenda1', 'MsFerndale']
# ['eNCA', 'MichelleL_Craig']
# ['LwaziPakade', 'MatebeseIam']
# ['gugumfuphi', 'OldMutualSA']
# ['Thy_Will', 'JLephalala']
# ['NorthWestZA', 'dhet4']
# ['letsoalofm', 'JustFoza']
# ['ThusiSabelo', 'enca']
# ['llspeelman', 'Trevornoah']
# ['RitsieMashale', 'tedxcapetown']
# ['rlimbanda', 'tedxcapetown']
# ['SMahomed10', 'tedxcapetown']
# ['alet87', 'Netwerk24Berig']
# ['Afrinnovator', 'NathanNgumi']
# ['CassperNyovest', 'JustFoza']
# ['jazz2ben', 'AfricanDialogue']
# ['Pontsho_Pilane', 'ietskaylo']
# ['lex_bess', 'iamjrnkosi']
# ['ANC', 'Cee_Wayne']
# ['xonecole', 'gee_MSFT']
# ['', 'Mora_Tanez']
# ['equal_education', 'our']
# ['WitsUniversity', 'equal_education']
# ['KennyMapakisha', 'SAPresident']
# ['eNCA', 'OFMNews9497']
# ['The_KYLN', 'novaramedia']
# ['snosibiya', 'DUT_Tweets']
# ['mbozulu93', 'protesting']
# ['mbozulu93', '263Chat']
# ['UllenderKabayi', 'Sentletse']
# ['Lesufi', 'fofgirl']
# ['RSAPresident', 'sparara012']
# ['NicoleBombard', 'eNCA']
# ['veezmbesa', 'uZamo_']
# ['neo_ick', 'bouga2pic']
# ['MaraSiyah', 'LundiPetelo']
# ['sir_hz', 'siya_raymond']
# ['eNCA', 'BAFO_DLOMO']
# ['eNCA', 'Teerz_world']
# ['Moses_Nku', 'bonang_m']
# ['andiMakinana', 'City_Press']
# ['eNCA', 'Soxx_24']
# ['Bontleful1', 'Njabs_MSFT']
# ['Mathiboo', 'enca']
# ['Mathiboo', 'Bongiwe_Khumalo']
# ['tap_it_lo', 'akaworldwide']
# ['Sqdrnleader', 'large']
# ['Bontleful1', 'Trixx_Ray']
# ['Ray_Kamolane', 'eNCA']
# ['_TheBang_', 'Luthility']
# ['Sthembisoh_', 'glorymachaka']
# ['Egypt_Exodus', 'TakeThatDarwin']
# ['_TheBang_', 'Ramashia3']
# ['akaworldwide', 'SamirSimelane']
# ['billyx2010', 'KrilaGP']
# ['Sthe_OoraModise', 'glorychakido']
# ['glorymachaka', 'glorychakido']
# ['mashiyanef', 'bladenzimandemp']
# ['eNCA', 'mashiyanef']
# ['DihoT27', 'SASCO_Jikelelepic']
# ['tumisangmafora', 'Sentletse']
# ['eNCA', 'PhiwahJnr']
# ['_TheBang_', 'Edd_Everything']
# ['KayzeePheHey', 'A_Melodious']
# ['Stelstudpar1', 'ThokozaniChili']
# ['StellenboschUnipic', 'ThokozaniChili']
# ['nontokozoz96', 'ChaseApparel']
# ['Emir_Sxllo', 'IllicitM']
# ['home', 'Brain_SoulKit']
# ['ntukzasa', 'thamihustla']
# ['eNCA', 'msizi_h']
# ['Lamola_Herold', 'akaworldwide']
# ['FollowbackJozi', 'iamLavida']
# ['NavyNkunaM', 'akaworldwide']
# ['Buhle_Nkonki', 'Soaqrate']
# ['akaworldwide', 'manjaphta']
# ['_kamo_3', 'akaworldwide']
# ['Its_Kemistry', 'olwethu__thando']
# ['ZandyMahlangu', 'BokangWrote']
# ['alet87', 'Netwerk24']
# ['NkululekoNcana', 'AdHabb']
# ['BBAFans', 'TheMela22']
# ['Safmpmlive', 'EliasChinemore']
# ['siwedi', 'eNCA']
# ['SAPS', 'Mas__xX']
# ['lt_qha', 'na_sibanibani']
# ['myanc_', 'na_sibanibani']
# ['eNCA', 'sunnysidehobo1']
# ['eNCA', 'svester47']
# ['ewn', 'svester47']
# ['foxybingo', 'bingo_carol1964']
# ['TshenoloM', 'Tlouu_Kganyago']
# ['bacon_bastard', 'sabzgodlo']
# ...
# ['NguNikita', 'thedailyvox']
# ['TheJoyfulOne1', 'MbalulaFikile']
# ['wilfmoyo', 'ABasaJJ']
# ['tsholomash', 'DouglasKruger']
# ['HeraldPE', 'Wisaniirvin']
# ['NelaZ_Clouds', 'MissMaseti']
# ['eDOTZA', 'theafricanchild']
# ['SenSanders', 'GlenTyler']
# ['FootballFactly', 'Odhuno_Sila']
# ['Africarevolt', 'shandu009']
# ['MonyisiSA', 'Thato_Tweets']
# ['eNCA', 'DiKap_laMerveil']
# ['DevynStella', 'LonaN91']
# ['Taps_D', 'EFFStudents']
# ['noMoreANCcrime', 'MUTSHIDZI_R']
# ['MolapisiPetrose', 'Sthera_h']
# ['DalsinoFTB', 'ManUtd']
# ['BroadcastMoose', 'DalsinoFTB']
# ['PlayEnergyDrink', 'NeoBaepii']
# ['MbalulaFikile', 'tumore_mkp']
# ['NamAfricanist', 'N_Tumi_Rapitsi']
# ['rosaroja4rev', 'doc1tech']
# ['noMoreANCcrime', '4bitnamibia']
# ['Skhumba07', 'WitsServices']
# ['chatlas', 'kapist']
# ['SakhileMalo', 'akaworldwide']
# ['hlompho_sesele', 'MayBoiz']
# ['RealThado', 'JesusGraces']
# ['Sentletse', 'JohnnyGrundling']
# ['Reevolutionaire', 'tshepo_motsitsi']
# ['siyabonga10Oct', 'HMakenisi']
# ['_____2s____', 'Anele_Nzimande']
# ['LitsitsoPule', 'tito_mboweni']
# ['Gracolemeg', 'eNCA']
# ['Bhut_Zizi', 'SuperSportBlitz']
# ['mises', 'LGMarincowitz']
# ['Bhut_Zizi', 'Arsenal']
# ['wearyspice', 'iJesseWilliams']
# ['bona_baratile', 'WitsServices']
# ['WitsServices', 'DownFees']
# ['TheAxiom', 'ImBlackBond']
# ['Time2Coach', 'feminist_rogue']
# ['AndiMakinana', 'ScotchKopele']
# ['ketelwa', 'chatlas']
# ['Scelosomhlaba', 'ANDRISworldwide']
# ['Nombalison', 'Sentletse']
# ['PlayEnergyDrink', 'BeachBumPablo']
# ['linda_mlotshwa', 'ezra_mlotshwa']
# ['Anele_Nzimande', 'CandessK']
# ['HellieDuPreez', 'keamoRay']
# ['bonang_m', 'Zanele_Phill']
# ['sir_hz', 'KaizerChiefs']
# ['Sentletse', 'Mpk_Praise']
# ['Iam_Cgo', 'obakenism']
# ['mrspanaz', 'Sentletse']
# ['eNCA', 'Refiloe_Reelo']
# ['Meisie_La', 'Bee_Leh']
# ['AkhFromTheBlock', 'coovadiam']
# ['thulazondi_', 'kaylanpk']
# ['Thabang_mashigo', 'euphonik']
# ['SibuN', 'Refiloe_Reelo']
# ['eNCA', 'e1a2e5362e9e4c2']
# ['eNCA', 'salim_sgo']
# ['Oreo_Bingo', 'ShackEmpireSA']
# ['lukanyo_', 'MannzNotHot']
# ['TearDucks', 'taahir_']
# ['zilu_tiya', 'Dr_teedkfuze']
# ['KeituMasike', 'Sentletse']
# ['eNCA', 'MsiziMsizig']
# ['eNCA', 'tlhogii_n']
# ['eNCA', 'CanzMaCanz']
# ['Rolandschoeman', 'SharnaBanana18']
# ['Milisauthando', 'MafatleMH']
# ['palesamorudu', 'adsteedley']
# ['tonyhawk', 'HellieDuPreez']
# ['Ncumisa_qp', 'Boity']
# ['AskGregory', 'alispagnola']
# ['bulali', 'ThandoM_94']
# ['tookie_r', 'tilikishi']
# ['kii_bo', 'Ah_nayP']
# ['b_mdakane', 'DjSthenjwa']
# ['THIibzY', 'RasRayz']
# ['AndiMakinana', 'DaciousNchoe']
# ['JosMudau', 'Sentletse']
# ['Cecelibs', 'Sentletse']
# ['HellieDuPreez', 'News24']
# ['mthu_d', 'Boity']
# ['akaworldwide', 'PBKoitsioe_']
# ['Mo_Quincy', 'Sentletse']
# ['LastPadare', 'akaworldwide']
# ['DashExtremely', 'GBCUnltd']
# ['TBL_ZA', 'WitsUniversity']
# ['EmilyLyster', 'NosiphoL__']
# ['Da_Last_Leta', 'akaworldwide']
# ['Luthando_da1st', 'RasRayz']
# ['PatrickConroySA', 'ThabisoSithole']
# ['YasirYmalik53', 'jabu_johnson']
# ['akaworldwide', 'Coco_thafirst']
# ['loyisogola', 'LudidiVelani']
# ['ShoeshoeQhu', 'PatrickConroySA']
# ['stankofa', '_LizaH_']
# ['deadtinginnit', 'ImBlackBond']
# ['SiphoMazibuko', 'ABasaJJ']
# ['ReeZy_786', 'bymacgyver']
# ['mthimz', 'cputstudents']
# ['ma_Ndosi', 'Dichaba_']
# ['eNCA', 'noMoreANCcrime']
# ['_NigeriaSports', 'sinethembafp']
# ['MR_Ndilula_', 'f62e58c8d66848c']
# ['WHATOMGIoI', 'whitneyunpluged']
# ['Masefudi_', 'Reneilwe_Mapz']
# ['201315751', 'SABCiindaba']
# ['TlaleNthakz', 'eNCA']
# ['byelerato', 'Ah_nayP']
# ['LelaK__', 'Harold_Ferwood']
# ['NonhleBeryl', 'ImBlackBond']
# ['eNCA', 'SiPhZz']
# ['Caspar_Lee', 'Mika_Ngobeni']
# ['NeoBaepii', 'ImBlackBond']
# ['eNCA', 'Mpazz1']
# ['eNCA', 'AmlaGaddaffi']
# ['eNCA', 'ShreksBeloved']
# ['Kenyanfeminist', 'kavsmaina']
# ['malidollar', 'Aiandar']
# ['AndiMakinana', 'sbbalman']
# ['tjmanaga', 'PoliticZAR']
# ['jamesstyan', 'paulyberk']
# ['gavf1', 'News24']
# ['AndiMakinana', 'tshepo_motsitsi']
# ['Alta_rsa', 'DripDripSplash1']
# ['Sentletse', 'lhilhilicious']
# ['Mathiz_K', 'MTVNEWS']
# ['Luewellyn', 'yeOldeTestAcc']
# ['JustinThobejane', 'MphoMolepo_']
# ['avheani_', 'MO_kAtz7']
# ['eNCA', 'YoziMhleli']
# ['simphiwedana', 'Thanx13']
# ['MissWaqu', 'News24']
# ['LegsForDaAays', '1take2G']
# ['SindiswaDube_', 'ImBlackBond']
# ['EzethuButi', 'kgax']
# ['casspernyovest', 'Da_Last_Leta']
# ['AndiMakinana', 'Jose2ab']
# ['whatnownwabisa', 'Promqueen2']
# ['akaworldwide', 'Khanye_M']
# ['AndiMakinana', 'tsepomohapi36']
# ['Bulletmagolide', 'SizweDhlomo']
# ['Mukanya0101', 'humdrumtv']
# ['angeloclouw', 'NickkTitan']
# ['eNCA', '__lizwa']
# ['eNCA', 'TinyBubblez_']
# ['Talookii', 'artofkawaii']
# ['Lwezzy_lu', 'SizweDhlomo']
# ['Lean3JvV', 'ImBlackBond']
# ['eNCA', 'TiChitsinde']
# ['casspernyovest', 'Mara_mbangc']
# ['SamirSimelane', 'mmsindo74']
# ['thereal_kmosh', 'MyLifeAsSne']
# ['IAmPaliey', 'KingKhanyi_']
# ['KgosiLesedi', 'MastercardMEA']
# ['eNCA', 'FrancinSaespoir']
# ['WakeupPeopIe', 'Da_Last_Leta']
# ['NickkTitan', 'MaBrie_Mongwato']
# ['artofkawaii', 'janaaier']
# ['MsOlwethu_', 'IamClaro']
# ['tiisetsogama', 'eNCA']
# ['mmkaygirl', 'WitsFMF']
# ['eNCA', 'JGLetoaba']
# ['AGronemeyer', 'FlutterbysRFree']
# ['eNCA', 'AmagodukaFest']
# ['Tekz17', 'Zandalee_Zwane']
# ['Ah_nayP', 'na_sibanibani']
# ['buyieKudos', 'akaworldwide']
# ['simphiwedana', 'Entle_Pule']
# ['MpiloNdlovu_', 'SexyMauritius']
# ['SimiNkosi', 'Mpho_Qtee']
# ['casspernyovest', 'SammyKinz111']
# ['Nduduzo86', 'TrendyBongx']
# ['SimaRulz', 'Courtz_Elson']
# ['eNCA', 'CallMe_LTee']
# ['Tiisetso_Phetla', 'Sets_Matubzz']
# ['eNCA', 'Da_Last_Leta']
# ['Kate_xxii', '_SPE_EDY_']
# ['TheSpecialBaby', 'Lee_hle2']
# ['eNCA', 'Boskasie_']
# ['eNCA', 'Gee_Skiti']
# ['Whisability', 'KNKhunou']
# ['nonniemathebula', 'KgolofeloO']
# ['Funzani_', 'CommyInABenz']
# ['Dichaba_', 'LlewellynLamber']
# ['Lunga_RH', 'SirDutch_Madrid']
# ['POWER987News', 'AGronemeyer']
# ['loyisogola', 'lelo_moore']
# ['hector_lose', 'Sentletse']
# ['Dylan_Paterson', 'ClxssicsOnly']
# ['CastleLagerSA', 'amyhlati_co']
# ['noMoreANCcrime', 'DeepMarvin']
# ['Feather_Ruffler', 'Sentletse']
# ['Charly216', 'LethaboCM']
# ['Ipeleng101', 'News24']
# ['SizweDhlomo', 'ziwelene']
# ['Vuyie', 'Sentletse']
# ['loyisogola', 'alutaningiza']
# ['Rosepetalsz', 'Sentletse']
# ['thecrimson', 'Ba_ntu']
# ['Taefresh_', 'Thobeofheart']
# ['atishjogi', 'Tho_Beee']
# ['eNCA', 'ThembiMrototo']
# ['MeliLumko', 'MrCashtime']
# ['katsethekat', 'ke_slaga']
# ['LuloCafe', 'TheRealMsParty']
# ['bona_baratile', 'elllekay1']
# ['Vhadiks', 'MissNono10_30']
# ['fifingwaneza', 'thandompembe']
# ['Ray_Kamolane', 'News24']
# ['SINDY_EC', 'roliphant6']
# ['TP_Toes10', 'Africa665']
# ['eNCA', 'mrgmawasha']
# ['TP_Toes10', 'anathiamantlane']
# ['Larryngitis', 'snash_145']
# ['eNCA', 'Jelly_Mank']
# ['business', 'tommykwela']
# ['BerkleeCollege', 'Penxenxe']
# ['Nedbank', 'Penxenxe']
# ['WOOLWORTHS_SA', 'Penxenxe']
# ['eNCA', 'ImraanAkhalwaya']
# ['Msizi_M', 'eNCA']
# ['LAWRENCABLE', 'eNCA']
# ['eNCA', 'Tebatso_2']
# ['PeterTerry3', 'Forbes']
# ['eNCA', 'corne06946803']
# ['StarKhulu', 'donnygondwe']
# ['eNCA', 'Lufuno45']
# ['eNCA', 'LOTv_Production']
# ['misshalle_sa', 'akaworldwide']
# ['realnickjgood', 'casspernyovest']
# ['eNCA', 'MGegana7']
# ['mona_rat', 'Ah_nayP']
# ['MhanaDyondzi', 'Tinustali']
# ['casspernyovest', 'Africa665']
# ['DirtyLykSwine', 'Bones_Marapo']
# ['SeanMagner', 'Nick_Frost']
# ['eNCA', '74LER']
# ['GreatestQuotes', 'RyanKurtJacobs']
# ['FlyingFishSA', 'KgosiLesedi']
# ['comment_chari', '2Tainted4Wrdz']
# ['sky_heavens', '_Minno_']
# ['Ah_nayP', 'tumisole']
# ['_JoyNicole', 'I_am_not_Deano']
# ['eNCA', 'MbebeAzola1']
# ['Tmanyathela', '_Didintle_m']
# ['savagesiafu', 'MccowenSandy']
# ['eNCA', 'oscark_']
# ['Retla_SweetChix', 'Da_Last_Leta']
# ['Aluxolo_Ngci', 'Anele_Nzimande']
# ['Sanchlet', '_Spheezo']
# ['VeeKayChili', 'MzCoco_Loco']
# ['lukewaltham', 'BrUcE__1j']
# ['Naturally_Lihle', 'Mark_Akol']
# ['I_Nkunzi', 'DjSthenjwa']
# ['eNCA', 'lakheda1031']
# ['Petty__Sue', 'dengcebz']
# ['Thabangdijamere', 'JamesRUU']
# ['eNCA', 'Charly216']
# ['michell4God', 'Manhle150']
# ['SEBEBE28', 'Moroka_n']
# ['MTshwete', 'muhammad_c']
# ['Piggihigoo', 'SharnaBanana18']
# ['GavinCame', 'palesamorudu']
# ['_Dingz', 'fixiontheboy']
# ['loyisogola', 'Zee_mazibuko']
# ['educationarena', 'CandessK']
# ['RedEmpressC', 'News24']
# ['madonda_23168', 'akaworldwide']
# ['LondaNtuli', 'ABasaJJ']
# ['Nomah_NL', 'shandu009']
# ['okaSikhakhane', 'akaworldwide']
# ['bee_dyasi', 'taythenomad']
# ['RoyalSuaveSA', 'akaworldwide']
# ['bongiwe_fiona', 'zee_nhle1']
# ['News24', 'Skinstad']
# ['anzathiba', 'News24']
# ['MashalaKwape', 'sa_lottery']
# ['ZenizoleGqada', 'Ghamu_']
# ['Mfundo_Cy', 'akaworldwide']
# ['UnDEANiable', '_Thembz_']
# ['EricJWest', 'SuperRedRanga']
# ['OwaFlopo', 'mbats99']
# ['ZeEzY92', 'eNCA']
# ['Fanz_Mafuze', 'JacaNews']
# ['hermzah', 'Njewizzyk']
# ['DumbaMcwane', 'b_bongzeey']
# ['Inamucoalice', 'kalisach']
# ['_MissMajola', 'Doughnarld']
# ['OfficialPSL', 'JeleBonele']
# ['Jnr_B', 'bonkers_bee']
# ['Tsaki_cocco16', 'akaworldwide']
# ['ronniie__xo', 'Mawande_RSA']
# ['SthembelaM', 'MbalulaFikile']
# ['MbamiG', 'LotfiWada']
# ['RethabileDonald', 'akaworldwide']
# ['b_bongzeey', 'casspernyovest']
# ['will_dhliwayo', 'casspernyovest']
# ['casspernyovest', 'Felicity_M2']
# ['Cristiano', 'NeoDinero']
# ['ronniie__xo', 'MetjahLeague']
# ['akaworldwide', 'Tebza808']
# ['will_dhliwayo', 'akaworldwide']
# ['Lesufi', 'Afrocast']
# ['dashezz', 'Bongiey_N']
# ['eNCA', 'shandu009']
# ['_Khanyisile__', 'casspernyovest']
# ['Charly216', 'akaworldwide']
# ['kennyDior', 'akaworldwide']
# ['akaworldwide', 'MetjahLeague']
# ['Tarrii_26', 'akaworldwide']
# ['RonPipes', 'akaworldwide']
# ['Vus_C', 'akaworldwide']
# ['missphly_mel', 'akaworldwide']
# ['MlaNdabase', 'casspernyovest']
# ['chan_Nav', 'helenketting']
# ['_Khanyisile__', 'SeanTheTerrible']
# ['Sir_C_E_P', 'Cc_Paw']
# ['KarenFourie3', 'eNCA']
# ['uMandlakazi', 'Lungee_Luu']
# ['_Nonjay_joy', 'ItuMahuma_']
# ['k_mamps', 'NolenceMashego']
# ['NamAfricanist', 'NickkTitan']
# ['AmishSiwa', 'ntusit']
# ['samela_samz', 'Zimkhitha_']
# ['tebogophaho', 'PhiweBacela']
# ['lesterkk', 'Africa665']
# ['Stevie_Madisha', 'miss_neoentle']
# ['eNCA', 'Valeri_ey']
# ['Misah_Mxo', 'SWoniwe']
# ['_Khanyisile__', 'Mosensei']
# ['eNCA', 'magezi_mzamani']
# ['Alex_sedibe', 'akaworldwide']
# ['servalshuttle', 'SihleSocishe']
# ['bmtcool', 'DianeBrownSA_']
# ['Mabasaa', 'True_Lolita']
# ['eNCA', 'SharnaBanana18']
# ['Lister_Theman', 'eNCA']
# ['News24', 'MphoMolepo_']
# ['TheRealPatel', 'WitsServices']
# ['eNCA', '_AndiM__']
# ['Sboh_L', 'akaworldwide']
# ['NOnxZee', 'MuscIeFitness']
# ['eNCA', 'MrMhla2U']
# ['caseyvm123', 'tsholomash']
# ['loyisogola', 'Carol_17523']
# ['khanyilyt', 'tshepomaz']
# ['DepressiaDube', 'ManyamaLopang']
# ['eNCA', 'SiyaBunny']
# ['LesegoTsiu1', 'eNCA']
# ['scott_hunt', 'ChiefThabo']
# ['rposervicessa', 'eNCA']
# ['I_Am_Le_Sobz', 'News24']
# ['Duxtch', 'Naledi__S']
# ['QueenK_745', 'KayB_Eezy']
# ['WriterDMDiaz', 'eNCA']
# ['Gosiame_sMurphy', 'Scripture_Truth']
# ['SetjaDiphokoSA', 'guardian']
# ['eNCA', 'Zoe_Goduka']
# ['thequote', 'firdausk01']
# ['Xolisa_Kula', 'Anele_Nzimande']
# ['thatguylebone', 'Eva_tshidi']
# ['Ncuresma', 'Naleli_']
# ['Thobile630', 'mysticsausage']
# ['IamMzilikazi', 'ThefabulousAn']
# ['neofrmthematrix', 'News24']
# ['DMvHeerden', 'News24']
# ['rayrendani', 'ANCYL_Tukkies']
# ['Caro1Graham', 'vandortaj']
# ['eNCA', 'KsKhathi']
# ['Mngxitama', 'RamaboduObakeng']
# ['Mmatseleng_C', 'eNCA']
# ['ndofirean', 'eNCA']
# ['Teekay_61029', 'LuloCafe']
# ['A_Cwayitile', 'Sthe_Y']
# ['brandon19hall', 'eNCA']
# ['khaleesego', 'LuloCafe']
# ['noni_mkhwanazi', 'phindamnerro']
# ['chichaboy_Cadra', 'KgosiBodibeng']
# ['IamMzilikazi', '_CrUnKaY_']
# ['MARYAMALKHAWAJA', 'DEWebster']
# ['FloMasebe', 'noni_mkhwanazi']
# ['chichaboy_Cadra', 'JonB_954']
# ['sabz_digital', 'gwannakop']
# ['Credo_Liyo', 'lecrae']
# ['bahumimokotedi1', 'Zimerian']
# ['nkosiab', 'Mz_umXhosa']
# ['JohannBiermann1', 'TebsaMoks']
# ['k_mamps', 'billysigudla']
# ['yuki_noire', 'FactsOfSchool']
# ['mowgliwilde', 'shaunking']
# ['Don_Chello', 'KarenAllenIntl']
# ['raediology', 'CarinaConradie']
# ['OsakiRomeo_', 'TheJamaJack']
# ['Mzo_honcho', 'UberFacts']
# ['UCT_PMF', 'k_mamps']
# ['Zimasile_', 'bfrolick']
# ['keatzkorevaar', 'MyNamesTodd']
# ['CeliStewart', 'Sentletse']
# ['rupikaur_', 'MtembuNtsika']
# ['NamAfricanist', 'MrImJustSayin']
# ['sydney263', 'dailynation']
# ['WILDFOXCOUTURE', 'LolaMonareng']
# ['SayEntrepreneur', 'dailynation']
# ['KomradeGeorge', 'dailynation']
# ['Cheeky_White', 'AfricafactsORG']
# ['NamAfricanist', 'Bathandwa0702']
# ['baaspole', 'Wwm_Shakespeare']
# ['BraAubrey', 'LindoLayi']
# ['eNCA', 'LuluMichyChan']
# ['Wuffco', 'kgaugelo74']
# ['HuffPost', 'EsmeArendse']
# ['mashiyanef', 'mabasoirvine']
# ['beekay104', 'GwedeUncle']
# ['Ms_Onesimo', 'sm_sabela']
# ['palesamorudu', 'nuthinfunnytsay']
# ['thulasindi', 'Vuyi_Zondi']
# ['tebogomphane', 'barrybateman']
# ['stash_jack', 'Le_Rots']
# ['MsLeloB', 'Sentletse']
# ['eNCA', 'marrakurru']
# ['raitlhwane', 'bobashman1']
# ['tebogomphane', 'vodkadubeel']
# ['SeanMagner', 'comradesipho']
# ['ntvkenya', 'ThefabulousAn']
# ['MinetteJohnson', 'FatimaFbomb']
# ['TonwaTai', 'denniskioko']
# ['eNCA', 'NawaneKhomo']
# ['eNCA', 'omara_tebza']
# ['Philas4', 'Sentletse']
# ['MyCityByNight', 'NattyGov']
# ['tununu3', 'jacques_julius']
# ['africasacountry', 'callistusmlk']
# ['BlckPorcelain', 'CatchTheBaby']
# ['TheresaTaylorZA', 'Anele_Nzimande']
# ['PWBotes', 'LilMissDudu']
# ['NRoynon', 'walterpike']
# ['eNCA', 'Bruceps']
# ['Sive_N', 'Sinethemba_S']
# ['IamMzilikazi', '2miefaith_to_me']
# ['eNCA', 'AmericanAfrica']
# ['eNCA', 'khotsoDM']
# ['lebompshe', 'Blixempie555']
# ['ThabileNgwato', 'Thabs136']
# ['kagisoMoi', 'trendinaliaZA']
# ['zukoZEKA', 'Sentletse']
# ['Sentletse', 'AfrikanJeanyus']
# ['bulali', 'palesamorudu']
# ['everndigowa', 'utopianindigent']
# ['88KOS', 'patrickhealynyt']
# ['ZeenatPatel01', 'UPTuks']
# ['Time2Coach', 'na_sibanibani']
# ['eNCA', 'teamSA4eva']
# ['AlterEgoInRF', 'na_sibanibani']
# ['JDJ67328056', 'blk_dandelion']
# ['missbolani', 'ImBlackBond']
# ['eNCA', 'Duanne_M']
# ['KrustAlmighty', 'palesamorudu']
# ['im_an_african', 'CausticPop']
# ['eNCA', 'JerryMpiana']
# ['Esquire_4_Hire', 'News24']
# ['eNCA', 'firdausk01']
# ['leebo_letompa', 'News24']
# ['FreeLefase', 'machaka']
# ['reywan8', 'paIIomniall']
# ['tsholomash', 'jjb9876']
# ['WomanDoItAll', 'KK_KingKokii']
# ['HalalaCongrats', 'mbindwane']
# ['nsukuvalentia', 'gpreller']
# ['_nhlanhla_ngubo', 'casspernyovest']
# ['eNCA', 'Nkulee_Njilo']
# ['mogaumabapa', 'ronesh']
# ['LLLMaties', 'JonnoDale']
# ['ZwaneKhabo', 'Sentletse']
# ['eNCA', 'GeneFMyburgh']
# ['tilhelhem', 'Sangweni_Sne']
# ['DonLubisi', 'EliasChinemore']
# ['Remo083', 'ThabileNgwato']
# ['Jakes_66900', 'Sentletse']
# ['Kuchumele', 'iamSivN']
# ['eNCA', 'Thats_Mel_M']
# ['Sentletse', 'RealQabela']
# ['Aphiwe_Mene', 'Simni89']
# ['eNCA', 'MAVoges']
# ['yolande_kwinana', 'News24']
# ['SandiSplash', 'Nedbank']
# ['Caspar_Lee', 'LianaRktn']
# ['eNCA', 'OboikanyoK']
# ['eNCA', 'Tsoli07']
# ['eNCA', 'ingy_n']
# ['eNCA', 'CampusMarketing']
# ['Stevie_Madisha', 'ApexF']
# ['Sentletse', 'Precious_LK']
# ['SokoolZA', 'teabagcc']
# ['lattesuggs', 'Amanda_Aphane']
# ['Adambarnes37', 'frankiemuniz']
# ['Gigi_Lamayne', 'MrPinkyPinky']
# ['thabomoetji', 'palesamorudu']
# ['yonondy', 'SeloneM']
# ['Nah_ledi', 'Knowzy_']
# ['qz', 'kF18']
# ['shxxriv', 'Caspar_Lee']
# ['Kayleen_Canari', 'Caspar_Lee']
# ['HashtagRadio', 'NdabaBongi']
# ['artofkawaii', 'HerSlayship']
# ['JCos01', 'bradd_james']
# ['Lungisa35', 'mnikani']
# ['Sabelo912', 'KingMahlaba']
# ['eNCA', 'TheRealDikeledi']
# ['DASOUCT', 'Harold_Ferwood']
# ['mukhudit', 'rayvicani']
# ['Neo_Phadi', 'utopianindigent']
# ['utopianindigent', 'Slender_Vee']
# ['Noooooooonie', 'UPTuks']
# ['eNCA', 'BradyLeanne']
# ['blessingweezy', 'NyashaMelGrace']
# ['ShortySenyolo', 'manjaphta']
# ['ThisIsBusi', 'GuruSona85']
# ['01Moshimanyana', 'MbalulaFikile']
# ['loyisogola', 'AmagodukaFest']
# ['JohannBiermann1', 'Blee_anca']
# ['neofrmthematrix', 'ABdeVilliers17']
# ['DDilebo', 'thedailyvox']
# ['eNCA', 'PabiJustHuman']
# ['Bella_Botle', 'eNCA']
# ['NamAfricanist', 'tucher1000']
# ['loyisogola', 'TshaweNkosi']
# ['loyisogola', 'Soso_Mdani']
# ['Anatinus', 'MutatedPear']
# ['MutatedPear', 'Anele_Nzimande']
# ['LisaTheLacebean', '_OmphileM_']
# ['Tina_Braz', 'Le_Rots']
# ['Harold_Ferwood', 'SirMaConcepts']
# ['Nxibelo_S', 'Sentletse']
# ['loyisogola', 'AtaliaLesego']
# ['eNCA', 'Tshepiso_29']
# ['Real_IndiaBlack', 'njabulonkosi']
# ['kelokialism1', 'palesamorudu']
# ['DannMwangi', 'ThefabulousAn']
# ['palesamorudu', 'Essential_KJ']
# ['Uncle_JayB', 'MidgetRacer93']
# ['KingKhanyi_', 'RhodesMustFall']
# ['nang_usikabopha', 'mabatamela']
# ['XolaniMade', 'palesamorudu']
# ['fjdhgskzgsjsh', 'palesamorudu']
# ['eNCA', 'karabzy']
# 46386

# %%
# Perform network analysis on high profile #FeesMustFall users
 
# Create graph by adding edges from ntwrk
G2 = nx.Graph()

count = 0
for node_1, node_2 in ntwrk:
    G2.add_edge(node_1, node_2, weight=1)
    if count == 150:
        break
    count+=1
    
print("The graph has %d nodes with %d edges" % (nx.number_of_nodes(G2), nx.number_of_edges(G2)))

pos = nx.layout.spring_layout(G2)

#Create Edges
edge_trace = go.Scatter(
    x=[],
    y=[],
    line=dict(width=0.5,color='#888'),
    hoverinfo='none',
    mode='lines')

for edge in G2.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_trace['x'] += tuple([x0, x1, None])
    edge_trace['y'] += tuple([y0, y1, None])
    
node_trace = go.Scatter(
    x=[],
    y=[],
    text=[],
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        colorscale='Electric',
        reversescale=True,
        color=[],
        size=10,
        colorbar=dict(
            thickness=15,
            title='Number of Node Connections',
            xanchor='left',
            titleside='right'
        ),  
        line=dict(width=2)))
for node in G2.nodes():
    x, y = pos[node]
    node_trace['x'] += tuple([x])
    node_trace['y'] += tuple([y])
    
#add color to node points
for node, adjacencies in enumerate(G2.adjacency()):
    node_trace['marker']['color']+=tuple([len(adjacencies[1])])
    node_info = 'Name: ' + str(adjacencies[0]) + '<br># of connections: '+str(len(adjacencies[1]))
    node_trace['text']+=tuple([node_info])
    
fig = go.Figure(data=[edge_trace, node_trace],
         layout=go.Layout(
            title='Network graph of high profile #FeesMustFall participants',
            titlefont=dict(size=16),
            showlegend=False,
            hovermode='closest',
            margin=dict(b=20,l=5,r=5,t=40),
            annotations=[ dict(
                showarrow=False,
                xref="paper", yref="paper",
                x=0.005, y=-0.002 ) ],
            xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
            yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

fig

# %% [raw]
# From the analysis above, we can identify MCEBO, ETC as key participants in the movements. There will be key participants in the movement who are not identified above as a result of Twitter inactivity. However, history shows that the central players are indeed key figures in the protest...

# %% [markdown]
# #### Summary of findings

# %% [markdown]
# ### Objective 3: Determining public perception towards the protests
# #### Text sentiment analysis
# TextBlob is built over the NLTK library. The library aids sentiment analysis by:
# 1. Tokenising the tweet i.e. splitting the words from the body of the text.
# 2. Removing stopwords (words that do not impact sentiment).
# 3. Passing tokens through a sentiment classifier - this classifier has been trained on a labelled movie reviews dataset using Naive Bayes.
# 4. Assigning a polarity values to each tweet - a high values indicated positive sentiment.
#
# The classifier groups tweets into three classes:
# 1. Positive: Tweets that have an optimistic outlook on the #FeesMustFall movement.
# 2. Neutral: Tweets that are neither positive nor negative on the topic.
# 3. Negative: Tweets surrounding negative sentiment in relation to #FeesMustFall
#
# vaderSentiment (Valence Aware Dictionary and sEntiment Reasoner) is another tool used to classify tweet sentiment. The process followed is similar to the one described above until the final step, where vaderSentiment uses different training data and models to assign sentiment polarity scores. More information can be found [here](http://comp.social.gatech.edu/papers/icwsm14.vader.hutto.pdf).
#
# In order to anaylse performance of the two models, the sentiment on the first 100 tweets is manually attributed. This is then compared to each respective model's predicted sentiment. The results are presented in the form of an ROC curve.
#
# Because the sentiment analysis includes three classes, regular binary classification cannot be used. A OneVsAll multiclass classification technique is adopted. This entails plotting an ROC curve for each class where that class is considered the 'positive' class and all other classes are considered the 'negative' class. This technique is applied to both sentiment analysis models.

# %%
# Perform sentiment analysis
# All data is prepared in this cell - plots are completed in later cells

def clean_tweet(tweet): 
    '''Cleans tweets by removing links, special characters 
    using regex statements.'''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", 
                           tweet).split()) 

def is_english(tweet):  
    '''Returns true if the tweet is in English. Returns False if
    the tweet is not English or if it returns an error'''
    try:
        if detect(tweet) == 'en':
            return True
        else:
            return False
    except:
        return False
    
# Create functions for TextBlob sentiment analysis
def get_tweet_sentiment_score(tweet): 
    '''Takes a tweet as an input and returns its sentiment polarity score'''
    analysis = TextBlob(clean_tweet(tweet)) 
    return analysis.sentiment.polarity

def assign_tweet_sentiment(polarity, threshold):
    '''Takes 2 arguments:
    1. The polarity score for a tweet
    2. The threshold above which a tweet is considered to have positive polarity
    Returns the sentiment of the tweet (positive, negative or neutral)'''
    if polarity > threshold: 
        return 'Positive'
    elif polarity == threshold: 
        return 'Neutral'
    else: 
        return 'Negative'
    
# Create function for vaderSentiment analysis
def compound_score(tweet):
    '''Takes a tweet as an input, cleans the tweet and returns
    the vaderSentiment compound polarity score'''
    analyzer = SentimentIntensityAnalyzer()
    tweet = clean_tweet(tweet)
    return analyzer.polarity_scores(tweet)['compound']
    
# Replicate df to be manipulated
df_man = df.iloc[:]

# Limit the analysis to tweets in English as the TextBlob library was trained on English data
df_man = df_man[df_man.text.apply(is_english)] # 22236 tweets are removed

# Perform TextBlob sentiment analysis
df_man['TB_sentiment_score'] = df_man.text.apply(get_tweet_sentiment_score)

# Perform vaderSentiment analysis
df_man['VS_sentiment_score'] = df_man.text.apply(compound_score)

df_man = df_man.reset_index()
df_man.drop(columns='index', inplace = True)

# Manually attribute sentiments for first 100 tweets to test accuracy
df_man['true_sentiment'] = 'n/a'
positive_pos = [1,3,4,5,7,9,10,11,13,15,17,18,
               22,23,24,25,26,27,28,29,30,35,
               37,39,46,50,55,56,57,58,59,66,
               67,68,69,73,74,75,77,78,79,83,
               87,88,89,95,96]
negative_pos = [12,85,98,99,100]
neutral_pos = [0,2,6,8,14,16,19,20,21,31,32,33,
              34,36,38,40,41,42,43,44,45,47,
              48,49,51,52,53,54,60,61,62,63,
              64,65,70,71,72,76,80,81,82,84,
              86,90,91,92,93,94,97]

df_man['true_sentiment'].loc[positive_pos] = 'Positive'
df_man['true_sentiment'].loc[negative_pos] = 'Negative'
df_man['true_sentiment'].loc[neutral_pos] = 'Neutral'

# Display sentiment columns
df_man.iloc[:3,[0,5,9,10,11]]

# %%
# Compute ROC curves for different techniques

classes = ['Positive', 'Negative', 'Neutral']
y_test_score = df_man.loc[:100][['true_sentiment', 'TB_sentiment_score', 'VS_sentiment_score']]

# Compute ROC curve and ROC area for each class (TextBlob)
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in classes : # we have three classes
    fpr[i], tpr[i], _ = roc_curve(y_test_score.true_sentiment, 
                                  y_test_score.TB_sentiment_score,
                                  pos_label = i)
    roc_auc[i] = auc(fpr[i], tpr[i])


# Plot of a ROC curve for a specific class
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(18, 6))    
for i in classes:
    ax1.plot(fpr[i], tpr[i], label= i + ' (area = %0.2f)' % roc_auc[i])
    ax1.plot([0, 1], [0, 1], 'k--')
    ax1.set_xlim([0.0, 1.0])
    ax1.set_ylim([0.0, 1.05])
    ax1.set_xlabel('False Positive Rate')
    ax1.set_ylabel('True Positive Rate')
    ax1.set_title('ROC curve: TextBlob')
    ax1.legend(loc="lower right")
    
# Compute ROC curve and ROC area for each class (vaderSentiment)
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in classes : # we have three classes
    fpr[i], tpr[i], _ = roc_curve(y_test_score.true_sentiment, 
                                  y_test_score.VS_sentiment_score,
                                  pos_label = i)
    roc_auc[i] = auc(fpr[i], tpr[i])
    
for i in classes:
    ax2.plot(fpr[i], tpr[i], label= i + ' (area = %0.2f)' % roc_auc[i])
    ax2.plot([0, 1], [0, 1], 'k--')
    ax2.set_xlim([0.0, 1.0])
    ax2.set_ylim([0.0, 1.05])
    ax2.set_xlabel('False Positive Rate')
    ax2.set_ylabel('True Positive Rate')
    ax2.set_title('ROC curve: vaderSentiment')
    ax2.legend(loc="lower right")
    
plt.show()

# %% [markdown]
# It is important to note that the neutral ROC curve is a non-informative. Because values within a small range of a polarity score of zero are classified as neutral, the threshold restriction would have to be expressed as an absolute value i.e. $|Threshold|<0.05$. For this reason, an ROC plot is not appropriate to illustrate the ideal threshold in this context - the curve is only included for completeness purposes.
#
# From the above, it can be seen that both methods perform similarly. Because the TextBlob method performs marginally better on the positive and negative sentiment curves, we adopt this classifier. The classifier is applied to all tweets - results are illustrated in the following cell.

# %%
# Visualise sentiment split

# Group data to analyse sentiment split
df_man['TB_sentiment_pred'] = df_man.TB_sentiment_score.apply(assign_tweet_sentiment, args = (0,))
sentiment_count = df_man.groupby('TB_sentiment_pred')[['username']].count()
sentiment_count.rename({'username': 'count'},
                 axis='columns', inplace = True)

sent_fig = make_subplots(rows=1, cols=2, specs=[[{'type':'pie'}, {'type':'xy'}]])

colors = ['gold', 'mediumturquoise', 'darkorange']

sent_fig.add_trace(go.Pie(labels=['Negative', 'Neutral', 'Positive'],
                          values=[sent for sent in sentiment_count['count']]),
                   row=1, col=1)
                          
sent_fig.update_traces(hoverinfo='label+percent', textinfo='value', textfont_size=20,
                      marker=dict(colors=colors, line=dict(color='#000000', width=2)))

sent_fig.update_layout(title={'text': '#FeesMustFall Sentiment Split',
                                'y':0.95,
                                'x':0.5,
                                'xanchor': 'center',
                                'yanchor': 'top'})

sent_fig.add_trace(go.Bar(x=['Negative', 'Neutral', 'Positive'],
                          y=[sent for sent in sentiment_count['count']],
                          marker_color=colors, showlegend = False),
                  row=1, col=2) 

sent_fig.show()
# Out:
# <div>
#
#
#             <div id="7f6d2032-cbf7-445b-a2c4-6d7575f0a37a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7f6d2032-cbf7-445b-a2c4-6d7575f0a37a")) {
#                     Plotly.newPlot(
#                         '7f6d2032-cbf7-445b-a2c4-6d7575f0a37a',
#                         [{"domain": {"x": [0.0, 0.45], "y": [0.0, 1.0]}, "hoverinfo": "label+percent", "labels": ["Negative", "Neutral", "Positive"], "marker": {"colors": ["gold", "mediumturquoise", "darkorange"], "line": {"color": "#000000", "width": 2}}, "textfont": {"size": 20}, "textinfo": "value", "type": "pie", "values": [52034, 180630, 97911]}, {"marker": {"color": ["gold", "mediumturquoise", "darkorange"]}, "showlegend": false, "type": "bar", "x": ["Negative", "Neutral", "Positive"], "xaxis": "x", "y": [52034, 180630, 97911], "yaxis": "y"}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# The above plots suggest that more than half of all tweets are neutral while positive sentiment towards the movement is almost double that of negative sentiment. Finally, a wordcloud is computed below.

# %%
# Create a string of all words in the tweets

text = " ".join([i for i in df_man['text']])

# Remove common, irrelevant words
stopwords = set(STOPWORDS)
more_stopwords = ['twitter','pic','https','ly','ow','FeesMustFall',
                 'co','za','need','bit','say','want','come','fb',
                 'fees','must','fall','RT','instagram','South','Africa']
for each_word in more_stopwords:
    stopwords.add(each_word)

wc = WordCloud(background_color="white", stopwords=stopwords, scale = 4,
               width=2500, height=1000).generate(text)

plt.figure(num=None, figsize=(15, 5), dpi=80)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# The word cloud above reaffirms the results seen in the split between positive and negative sentiment towards the movement. Words such as 'National Shutdown' and 'Free Education' take up large spaces in the word cloud and are terms likely to be used by those in favour of the movement. Negative words like 'fragmented' appear smaller on the word cloud reinforcing that there is a larger proportion of positive sentiment towards the movement.

# %% [markdown]
# #### Summary of findings
# While most of the tweets are neutral commentary on the topic, a larger proportion of the polar tweets tend to be encompass a positive outlook on the movement as opposed to a negative one.

# %% [markdown]
# ## Conclusion
#
# From the above analysis, three conclusions can be reached:
#
# 3. While negativity towards the movement exists, a larger proportion of tweeters view the movement in a positive light.
